# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsonbjr/Covid19_Crisis/blob/master/covid19_Brasil_23APR20_Novos_Graficosv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Autor: Nelson Biagio Junior
## Data: 21 MAR 2020

# %% [markdown]
# ## **OBTENDO DADOS E PREPARANDO O AMBIENTE**

# %%
# Importando Bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Set style & figures inline
sns.set()
# %matplotlib inline

# %%
casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.tail()
# Out:
#                 Province/State         Country/Region  ...  4/21/20  4/22/20
# 259  Saint Pierre and Miquelon                 France  ...        1        1
# 260                        NaN            South Sudan  ...        4        4
# 261                        NaN         Western Sahara  ...        6        6
# 262                        NaN  Sao Tome and Principe  ...        4        4
# 263                        NaN                  Yemen  ...        1        1
#
# [5 rows x 96 columns]

# %%
casos.rename(columns={'Country/Region' : 'Country'}, inplace = True)
casos.tail()
# Out:
#                 Province/State                Country  ...  4/21/20  4/22/20
# 259  Saint Pierre and Miquelon                 France  ...        1        1
# 260                        NaN            South Sudan  ...        4        4
# 261                        NaN         Western Sahara  ...        6        6
# 262                        NaN  Sao Tome and Principe  ...        4        4
# 263                        NaN                  Yemen  ...        1        1
#
# [5 rows x 96 columns]

# %% [markdown]
# ## **SELECIONANDO DADOS DO BRASIL**

# %%
casos_BR = casos[casos.Country == "Brazil"]
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  4/19/20  4/20/20  4/21/20  4/22/20
# 28            NaN  Brazil -14.235 -51.9253  ...    38654    40743    43079    45757
#
# [1 rows x 96 columns]

# %%
filtro_brasil = casos["Country"] == "Brazil"
casos.loc[filtro_brasil]
# Out:
#    Province/State Country     Lat     Long  ...  4/19/20  4/20/20  4/21/20  4/22/20
# 28            NaN  Brazil -14.235 -51.9253  ...    38654    40743    43079    45757
#
# [1 rows x 96 columns]

# %%
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  4/19/20  4/20/20  4/21/20  4/22/20
# 28            NaN  Brazil -14.235 -51.9253  ...    38654    40743    43079    45757
#
# [1 rows x 96 columns]

# %%
casos_BR = np.sum(casos_BR.iloc[ : , 4 : casos_BR.shape[1]]) ##Criando um índice atravez do atributo de data
casos_BR.index = pd.DatetimeIndex(casos_BR.index)
casos_BR.tail()
# Out:
# 2020-04-18    36658
# 2020-04-19    38654
# 2020-04-20    40743
# 2020-04-21    43079
# 2020-04-22    45757
# dtype: int64

# %%
casos_BR.plot() ##Gráfico com o número de casos do Brasil
plt.title('Numero de Casos - Brasil')
plt.show()

# %% [markdown]
# ## **MORTES POR COVID-19 NO BRASIL**

# %%
mortes = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
mortes.tail()
# Out:
#                 Province/State         Country/Region  ...  4/21/20  4/22/20
# 259  Saint Pierre and Miquelon                 France  ...        0        0
# 260                        NaN            South Sudan  ...        0        0
# 261                        NaN         Western Sahara  ...        0        0
# 262                        NaN  Sao Tome and Principe  ...        0        0
# 263                        NaN                  Yemen  ...        0        0
#
# [5 rows x 96 columns]

# %%
mortes.rename(columns={'Country/Region' : 'Country'}, inplace = True)
mortes.tail()
# Out:
#                 Province/State                Country  ...  4/21/20  4/22/20
# 259  Saint Pierre and Miquelon                 France  ...        0        0
# 260                        NaN            South Sudan  ...        0        0
# 261                        NaN         Western Sahara  ...        0        0
# 262                        NaN  Sao Tome and Principe  ...        0        0
# 263                        NaN                  Yemen  ...        0        0
#
# [5 rows x 96 columns]

# %%
mortes_BR = mortes[mortes.Country == "Brazil"] ## Selecionando os óbitos no Brasil
mortes_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  4/19/20  4/20/20  4/21/20  4/22/20
# 28            NaN  Brazil -14.235 -51.9253  ...     2462     2587     2741     2906
#
# [1 rows x 96 columns]

# %%
##Criando um índice atravez do atributo de data
mortes_BR = np.sum(mortes_BR.iloc[ : , 4 : mortes_BR.shape[1]])
mortes_BR.index = pd.DatetimeIndex(mortes_BR.index)
mortes_BR.tail()
# Out:
# 2020-04-18    2354
# 2020-04-19    2462
# 2020-04-20    2587
# 2020-04-21    2741
# 2020-04-22    2906
# dtype: int64

# %%
mortes_BR.plot() ##Gráfico com o número de mortes do Brasil
plt.title('Número de Óbitos - BR')
plt.show()

# %% [markdown]
# ## **MORTALIDADE NO BRASIL**

# %%
mortalidade_BR = (mortes_BR/casos_BR)*100
mortalidade_BR.tail(20)
# Out:
# 2020-04-03    3.964223
# 2020-04-04    4.295367
# 2020-04-05    4.366577
# 2020-04-06    4.637776
# 2020-04-07    4.888129
# 2020-04-08    5.064935
# 2020-04-09    5.250940
# 2020-04-10    5.382422
# 2020-04-11    5.422878
# 2020-04-12    5.510995
# 2020-04-13    5.667947
# 2020-04-14    6.064445
# 2020-04-15    6.129944
# 2020-04-16    6.323747
# 2020-04-17    6.356511
# 2020-04-18    6.421518
# 2020-04-19    6.369328
# 2020-04-20    6.349557
# 2020-04-21    6.362729
# 2020-04-22    6.350941
# dtype: float64

# %%
mortalidade_BR.plot()
plt.title('Taxa de Mortlidade - BR (%)')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES RECUPERADOS NO BRASIL**

# %%
recuperados = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
recuperados.shape
# Out:
# (250, 96)

# %%
recuperados.rename(columns={'Country/Region' : 'Country'}, inplace = True)
recuperados.tail()
# Out:
#                 Province/State                Country  ...  4/21/20  4/22/20
# 245  Saint Pierre and Miquelon                 France  ...        0        0
# 246                        NaN            South Sudan  ...        0        0
# 247                        NaN         Western Sahara  ...        0        0
# 248                        NaN  Sao Tome and Principe  ...        0        0
# 249                        NaN                  Yemen  ...        0        0
#
# [5 rows x 96 columns]

# %%
recuperados_BR = recuperados[recuperados.Country == "Brazil"]
recuperados_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  4/19/20  4/20/20  4/21/20  4/22/20
# 29            NaN  Brazil -14.235 -51.9253  ...    22130    22130    22991    25318
#
# [1 rows x 96 columns]

# %%
##Criando um índice atravez do atributo de data
recuperados_BR = np.sum(recuperados_BR.iloc[ : , 4 : recuperados_BR.shape[1]])
recuperados_BR.index = pd.DatetimeIndex(recuperados_BR.index)
recuperados_BR.tail()
# Out:
# 2020-04-18    14026
# 2020-04-19    22130
# 2020-04-20    22130
# 2020-04-21    22991
# 2020-04-22    25318
# dtype: int64

# %%
recuperados_BR.plot()
plt.title('Pacientes Recuperados - Brasil')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES ATIVOS NO BRASIL**

# %%
ativos_BR = casos_BR - (recuperados_BR+mortes_BR)
ativos_BR.tail()
# Out:
# 2020-04-18    20278
# 2020-04-19    14062
# 2020-04-20    16026
# 2020-04-21    17347
# 2020-04-22    17533
# dtype: int64

# %%
ativos_BR.plot()
plt.title('Pacientes Ativos - Brasil')
plt.show()

# %%
df = pd.concat([casos_BR, ativos_BR, recuperados_BR, mortes_BR], axis=1)
df.tail(80)
# Out:
#                 0      1      2     3
# 2020-02-03      0      0      0     0
# 2020-02-04      0      0      0     0
# 2020-02-05      0      0      0     0
# 2020-02-06      0      0      0     0
# 2020-02-07      0      0      0     0
# ...           ...    ...    ...   ...
# 2020-04-18  36658  20278  14026  2354
# 2020-04-19  38654  14062  22130  2462
# 2020-04-20  40743  16026  22130  2587
# 2020-04-21  43079  17347  22991  2741
# 2020-04-22  45757  17533  25318  2906
#
# [80 rows x 4 columns]

# %%
df.columns = (["casos", "ativos", "recuperados", "mortes"])
df.tail()
# Out:
#             casos  ativos  recuperados  mortes
# 2020-04-18  36658   20278        14026    2354
# 2020-04-19  38654   14062        22130    2462
# 2020-04-20  40743   16026        22130    2587
# 2020-04-21  43079   17347        22991    2741
# 2020-04-22  45757   17533        25318    2906

# %%
df.plot()
plt.title('Panorama Atual - Brasil')
plt.show()

# %% [markdown]
# ## **CALCULANDO O NÚMERO DE NOVOS CASOS NO BRASIL**

# %%
## O objetivo desta análise é calcular a taxa de crescimento da Covid19 no Brasil
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

df.drop(["Province/State", "Lat", "Long"], axis=1, inplace=True)

brasil = df.loc[df["Country/Region"] == "Brazil"].copy()
brasil.reset_index(drop=True, inplace=True)

brasil_t = brasil.T
brasil_t.drop("Country/Region", inplace=True)
brasil_t.columns = ["Casos"]
brasil_t.index.name = "Data"
brasil_t.index = pd.to_datetime(brasil_t.index)
brasil_t["Novos Casos"] = brasil_t["Casos"].diff()
brasil_t.tail(40)
# Out:
#             Casos Novos Casos
# Data
# 2020-03-14    151           0
# 2020-03-15    162          11
# 2020-03-16    200          38
# 2020-03-17    321         121
# 2020-03-18    372          51
# 2020-03-19    621         249
# 2020-03-20    793         172
# 2020-03-21   1021         228
# 2020-03-22   1546         525
# 2020-03-23   1924         378
# 2020-03-24   2247         323
# 2020-03-25   2554         307
# 2020-03-26   2985         431
# 2020-03-27   3417         432
# 2020-03-28   3904         487
# 2020-03-29   4256         352
# 2020-03-30   4579         323
# 2020-03-31   5717        1138
# 2020-04-01   6836        1119
# 2020-04-02   8044        1208
# 2020-04-03   9056        1012
# 2020-04-04  10360        1304
# 2020-04-05  11130         770
# 2020-04-06  12161        1031
# 2020-04-07  14034        1873
# 2020-04-08  16170        2136
# 2020-04-09  18092        1922
# 2020-04-10  19638        1546
# 2020-04-11  20727        1089
# 2020-04-12  22192        1465
# 2020-04-13  23430        1238
# 2020-04-14  25262        1832
# 2020-04-15  28320        3058
# 2020-04-16  30425        2105
# 2020-04-17  33682        3257
# 2020-04-18  36658        2976
# 2020-04-19  38654        1996
# 2020-04-20  40743        2089
# 2020-04-21  43079        2336
# 2020-04-22  45757        2678

# %%
brasil_t.plot()

# %% [markdown]
# ## **CALCULANDO A TAXA DE CRESCIMENTO NO BRASIL**

# %%
novos_casos = brasil_t["Casos"].diff()
novos_casos.tail()
# Out:
# Data
# 2020-04-18    2976
# 2020-04-19    1996
# 2020-04-20    2089
# 2020-04-21    2336
# 2020-04-22    2678
# Name: Casos, dtype: object

# %%
df = pd.concat([casos_BR, novos_casos], axis=1)
df.tail()
# Out:
#                 0 Casos
# 2020-04-18  36658  2976
# 2020-04-19  38654  1996
# 2020-04-20  40743  2089
# 2020-04-21  43079  2336
# 2020-04-22  45757  2678

# %%
df.columns = (["casos", "Novos Casos"])
df.tail()
# Out:
#             casos Novos Casos
# 2020-04-18  36658        2976
# 2020-04-19  38654        1996
# 2020-04-20  40743        2089
# 2020-04-21  43079        2336
# 2020-04-22  45757        2678

# %%
crescimento = (novos_casos[35:]/casos_BR[35:])*100
crescimento.tail(30)
# Out:
# Data
# 2020-03-24    14.3747
# 2020-03-25    12.0204
# 2020-03-26    14.4389
# 2020-03-27    12.6427
# 2020-03-28    12.4744
# 2020-03-29    8.27068
# 2020-03-30    7.05394
# 2020-03-31    19.9055
# 2020-04-01    16.3692
# 2020-04-02    15.0174
# 2020-04-03    11.1749
# 2020-04-04    12.5869
# 2020-04-05    6.91824
# 2020-04-06    8.47792
# 2020-04-07    13.3462
# 2020-04-08    13.2096
# 2020-04-09    10.6235
# 2020-04-10    7.87249
# 2020-04-11    5.25402
# 2020-04-12    6.60148
# 2020-04-13    5.28382
# 2020-04-14      7.252
# 2020-04-15     10.798
# 2020-04-16    6.91865
# 2020-04-17    9.66985
# 2020-04-18    8.11828
# 2020-04-19    5.16376
# 2020-04-20    5.12726
# 2020-04-21     5.4226
# 2020-04-22    5.85266
# dtype: object

# %%
crescimento.plot()
plt.title('Taxa de Crescimento Diario (%)')
plt.show()

# %% [markdown]
# # **Nova Visualização - Estados Brasileiros**

# %%
# Importando dados do dataset
data = pd.read_csv('https://brasil.io/dataset/covid19/caso?format=csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25944 entries, 0 to 25943
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            25944 non-null  object
#  1   state                           25944 non-null  object
#  2   city                            24886 non-null  object
#  3   place_type                      25944 non-null  object
#  4   confirmed                       25944 non-null  int64
#  5   deaths                          25944 non-null  int64
#  6   is_last                         25944 non-null  bool
#  7   estimated_population_2019       25528 non-null  float64
#  8   city_ibge_code                  25528 non-null  float64
#  9   confirmed_per_100k_inhabitants  25128 non-null  float64
#  10  death_rate                      6092 non-null   float64
# dtypes: bool(1), float64(4), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
data.head(n = 15)
# Out:
#           date state  ... confirmed_per_100k_inhabitants death_rate
# 0   2020-04-22    AC  ...                       78.65758        NaN
# 1   2020-04-22    AC  ...                        9.74089        NaN
# 2   2020-04-22    AC  ...                        5.65764        NaN
# 3   2020-04-22    AC  ...                      106.26993     0.0476
# 4   2020-04-22    AC  ...                        5.40424        NaN
# 5   2020-04-22    AC  ...                       42.22735     0.0407
# 6   2020-04-22    AC  ...                        8.68659        NaN
# 7   2020-04-22    AC  ...                       24.26483     0.0374
# 8   2020-04-22    AL  ...                        1.29452        NaN
# 9   2020-04-22    AL  ...                        3.66555        NaN
# 10  2020-04-22    AL  ...                        5.86407        NaN
# 11  2020-04-22    AL  ...                        6.40369     1.0000
# 12  2020-04-22    AL  ...                            NaN     0.2500
# 13  2020-04-22    AL  ...                       20.11879     0.0683
# 14  2020-04-22    AL  ...                       11.56047     0.1667
#
# [15 rows x 11 columns]

# %%
data.describe()
# Out:
#           confirmed        deaths  ...  confirmed_per_100k_inhabitants   death_rate
# count  25944.000000  25944.000000  ...                    25128.000000  6092.000000
# mean      42.437789      2.378585  ...                       10.100387     0.284106
# std      391.187994     27.324947  ...                       23.585475     0.325228
# min        0.000000      0.000000  ...                        0.002180     0.003400
# 25%        1.000000      0.000000  ...                        2.279770     0.052600
# 50%        2.000000      0.000000  ...                        4.964500     0.133300
# 75%        6.000000      0.000000  ...                       10.739700     0.400000
# max    15914.000000   1134.000000  ...                      947.402810     1.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# **Manipulando Dados**

# %%
# Dados por estado
data_states = data[data.place_type.eq('state')]
data_states.head(n = 15)
# Out:
#            date state  ... confirmed_per_100k_inhabitants death_rate
# 7    2020-04-22    AC  ...                       24.26483     0.0374
# 25   2020-04-22    AL  ...                        7.28121     0.0823
# 60   2020-04-22    AM  ...                       59.81281     0.0831
# 69   2020-04-22    AP  ...                       58.17453     0.0285
# 179  2020-04-22    BA  ...                       11.06026     0.0322
# 182  2020-04-22    DF  ...                       31.80480     0.0261
# 227  2020-04-22    ES  ...                       33.61825     0.0274
# 278  2020-04-22    GO  ...                        6.24078     0.0479
# 326  2020-04-22    MA  ...                       24.83329     0.0433
# 471  2020-04-22    MG  ...                        6.06081     0.0366
# 493  2020-04-22    MS  ...                        6.29726     0.0343
# 521  2020-04-22    MT  ...                        5.88325     0.0293
# 590  2020-04-22    PA  ...                       13.89072     0.0360
# 618  2020-04-22    PB  ...                        8.58609     0.1159
# 717  2020-04-22    PE  ...                       34.50848     0.0855
#
# [15 rows x 11 columns]

# %%
# Segregar dados de casos confirmados e mortes
data_states_confirmed = data_states[['date','state','confirmed']]
data_states_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1058 entries, 7 to 25943
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1058 non-null   object
#  1   state      1058 non-null   object
#  2   confirmed  1058 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 33.1+ KB

# %%
data_states_deaths = data_states[['date','state','deaths']]
data_states_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1058 entries, 7 to 25943
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1058 non-null   object
#  1   state   1058 non-null   object
#  2   deaths  1058 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 33.1+ KB

# %%
# Tabela de população de cada estado em 2019

states_pop = data_states[['state','estimated_population_2019']]
states_pop = states_pop.drop_duplicates()
states_pop.set_index('state', inplace = True)
states_pop
# Out:
#        estimated_population_2019
# state
# AC                      881935.0
# AL                     3337357.0
# AM                     4144597.0
# AP                      845731.0
# BA                    14873064.0
# DF                     3015268.0
# ES                     4018650.0
# GO                     7018354.0
# MA                     7075181.0
# MG                    21168791.0
# MS                     2778986.0
# MT                     3484466.0
# PA                     8602865.0
# PB                     4018127.0
# PE                     9557071.0
# PI                     3273227.0
# PR                    11433957.0
# RJ                    17264943.0
# RR                      605761.0
# RS                    11377239.0
# SC                     7164788.0
# SE                     2298696.0
# SP                    45919049.0
# TO                     1572866.0
# CE                     9132078.0
# RN                     3506853.0
# RO                     1777225.0

# %% [markdown]
# ## **Numero de Casos Confirmados**
# ## **Transformação de dados**

# %%
# Transformar dataframe de long para wide
data_cases = data_states_confirmed.pivot(index='state', columns='date', values='confirmed')
data_cases.head()
# Out:
# date   2020-02-25  2020-02-26  2020-02-27  ...  2020-04-20  2020-04-21  2020-04-22
# state                                      ...
# AC            NaN         NaN         NaN  ...       176.0       195.0       214.0
# AL            NaN         NaN         NaN  ...       171.0       210.0       243.0
# AM            NaN         NaN         NaN  ...      2160.0      2270.0      2479.0
# AP            NaN         NaN         NaN  ...       435.0       466.0       492.0
# BA            NaN         NaN         NaN  ...      1377.0      1504.0      1645.0
#
# [5 rows x 58 columns]

# %%
# Verificar index das observaçôes
data_cases.index
# Out:
# Index(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS',
#        'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC',
#        'SE', 'SP', 'TO'],
#       dtype='object', name='state')

# %%
# Trocando a indexação de estado por data
data_cases = data_cases.transpose()
data_cases
# Out:
# state          AC     AL      AM     AP  ...      SC     SE       SP    TO
# date                                     ...
# 2020-02-25    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-26    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-27    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-28    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-02-29    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-01    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-02    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-03    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-04    NaN    NaN     NaN    NaN  ...     NaN    NaN      3.0   NaN
# 2020-03-05    NaN    NaN     NaN    NaN  ...     NaN    NaN      6.0   NaN
# 2020-03-06    NaN    NaN     NaN    NaN  ...     NaN    NaN     10.0   NaN
# 2020-03-07    NaN    NaN     NaN    NaN  ...     NaN    NaN     13.0   NaN
# 2020-03-08    NaN    1.0     NaN    NaN  ...     NaN    NaN     16.0   NaN
# 2020-03-09    NaN    1.0     NaN    NaN  ...     NaN    NaN     16.0   NaN
# 2020-03-10    NaN    1.0     NaN    NaN  ...     NaN    NaN     19.0   NaN
# 2020-03-11    NaN    NaN     NaN    NaN  ...     NaN    NaN     30.0   NaN
# 2020-03-12    NaN    1.0     NaN    NaN  ...     2.0    NaN     46.0   NaN
# 2020-03-13    NaN    1.0     2.0    NaN  ...     3.0    NaN      NaN   NaN
# 2020-03-14    NaN    NaN     NaN    NaN  ...     5.0    1.0     65.0   NaN
# 2020-03-15    NaN    NaN     NaN    NaN  ...     6.0    NaN      NaN   NaN
# 2020-03-16    NaN    1.0     NaN    NaN  ...     7.0    5.0    152.0   NaN
# 2020-03-17    3.0    1.0     NaN    NaN  ...     7.0    NaN    164.0   NaN
# 2020-03-18    3.0    1.0     2.0    NaN  ...    14.0    6.0    240.0   1.0
# 2020-03-19    4.0    4.0     3.0    NaN  ...    21.0    NaN    286.0   1.0
# 2020-03-20    7.0    6.0     7.0    1.0  ...    40.0    7.0    396.0   1.0
# 2020-03-21   11.0    7.0    11.0    1.0  ...    57.0   10.0    396.0   2.0
# 2020-03-22   11.0    7.0    26.0    1.0  ...    68.0    NaN    631.0   5.0
# 2020-03-23   17.0    8.0    32.0    1.0  ...    86.0    NaN    745.0   7.0
# 2020-03-24   21.0   10.0    47.0    1.0  ...   109.0   15.0    810.0   7.0
# 2020-03-25   23.0   11.0    54.0    2.0  ...   122.0   16.0    862.0   7.0
# 2020-03-26   23.0   11.0    67.0    2.0  ...   149.0    NaN   1052.0   8.0
# 2020-03-27   25.0   12.0    81.0    3.0  ...   163.0   16.0   1223.0   9.0
# 2020-03-28   25.0   14.0   111.0    4.0  ...   184.0    NaN   1406.0   9.0
# 2020-03-29   34.0   17.0   140.0    8.0  ...   197.0    NaN   1451.0  10.0
# 2020-03-30   41.0   17.0   151.0    8.0  ...   219.0   18.0   1517.0  11.0
# 2020-03-31   42.0   18.0   175.0   10.0  ...   235.0   19.0   2339.0  12.0
# 2020-04-01   43.0   18.0   200.0   11.0  ...   247.0   22.0   2981.0  12.0
# 2020-04-02   45.0   18.0   229.0   12.0  ...   281.0   24.0   3506.0  12.0
# 2020-04-03   46.0   23.0   260.0   19.0  ...   301.0   27.0   4048.0  13.0
# 2020-04-04   46.0   23.0   311.0   29.0  ...   356.0   32.0   4466.0  16.0
# 2020-04-05   48.0   28.0   417.0   32.0  ...   379.0    NaN   4620.0  17.0
# 2020-04-06   50.0   31.0   532.0   39.0  ...   417.0   32.0   4866.0  19.0
# 2020-04-07   50.0   34.0   636.0   51.0  ...   457.0   36.0   5682.0  19.0
# 2020-04-08   58.0   37.0   804.0  107.0  ...   501.0   39.0   6708.0  23.0
# 2020-04-09   62.0   37.0   899.0  110.0  ...   693.0   40.0   7480.0  23.0
# 2020-04-10   70.0   45.0   981.0  166.0  ...   717.0   42.0   8216.0  23.0
# 2020-04-11   72.0   48.0  1049.0  193.0  ...   732.0   44.0   8419.0  25.0
# 2020-04-12   77.0   48.0  1206.0  237.0  ...   776.0    NaN   8755.0  26.0
# 2020-04-13   90.0   58.0  1275.0  244.0  ...   826.0   45.0   8895.0  26.0
# 2020-04-14   99.0   72.0  1484.0  308.0  ...   853.0   46.0   9371.0  27.0
# 2020-04-15  101.0   83.0  1554.0  342.0  ...   884.0   48.0  11043.0  29.0
# 2020-04-16  115.0   89.0  1719.0  362.0  ...   926.0   53.0  11568.0  31.0
# 2020-04-17  135.0  110.0  1809.0  375.0  ...   962.0   58.0  12841.0  32.0
# 2020-04-18  142.0  132.0  1897.0  400.0  ...   975.0   71.0  13894.0  33.0
# 2020-04-19  163.0  159.0  2044.0  416.0  ...  1025.0   86.0  14267.0  34.0
# 2020-04-20  176.0  171.0  2160.0  435.0  ...  1063.0   92.0  14580.0  35.0
# 2020-04-21  195.0  210.0  2270.0  466.0  ...  1091.0  117.0  15385.0  36.0
# 2020-04-22  214.0  243.0  2479.0  492.0  ...  1115.0  118.0  15914.0  37.0
#
# [58 rows x 27 columns]

# %%
# Verificar a indexação como data
data_cases.index
# Out:
# Index(['2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29',
#        '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10',
#        '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15',
#        '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#        '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30',
#        '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#        '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09',
#        '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14',
#        '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19',
#        '2020-04-20', '2020-04-21', '2020-04-22'],
#       dtype='object', name='date')

# %%
# Conversão do index para DateTimeIndex pois está como 'object'
datetime_index = pd.DatetimeIndex(data_cases.index)
data_cases.set_index(datetime_index, inplace = True)
# Verificar o index novamente
data_cases.index
# Out:
# DatetimeIndex(['2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28',
#                '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03',
#                '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07',
#                '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11',
#                '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15',
#                '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19',
#                '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23',
#                '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#                '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31',
#                '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#                '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08',
#                '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12',
#                '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16',
#                '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20',
#                '2020-04-21', '2020-04-22'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
# Existem NAs entre observações válidas, provavlemente houve um falta de informação para aquele estado naquele dia. Vamos considerar este valor igual ao último valor válido para aquele estado.
data_cases.fillna(method='ffill', inplace=True)
data_cases
# Out:
# state          AC     AL      AM     AP  ...      SC     SE       SP    TO
# date                                     ...
# 2020-02-25    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-26    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-27    NaN    NaN     NaN    NaN  ...     NaN    NaN      1.0   NaN
# 2020-02-28    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-02-29    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-01    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-02    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-03    NaN    NaN     NaN    NaN  ...     NaN    NaN      2.0   NaN
# 2020-03-04    NaN    NaN     NaN    NaN  ...     NaN    NaN      3.0   NaN
# 2020-03-05    NaN    NaN     NaN    NaN  ...     NaN    NaN      6.0   NaN
# 2020-03-06    NaN    NaN     NaN    NaN  ...     NaN    NaN     10.0   NaN
# 2020-03-07    NaN    NaN     NaN    NaN  ...     NaN    NaN     13.0   NaN
# 2020-03-08    NaN    1.0     NaN    NaN  ...     NaN    NaN     16.0   NaN
# 2020-03-09    NaN    1.0     NaN    NaN  ...     NaN    NaN     16.0   NaN
# 2020-03-10    NaN    1.0     NaN    NaN  ...     NaN    NaN     19.0   NaN
# 2020-03-11    NaN    1.0     NaN    NaN  ...     NaN    NaN     30.0   NaN
# 2020-03-12    NaN    1.0     NaN    NaN  ...     2.0    NaN     46.0   NaN
# 2020-03-13    NaN    1.0     2.0    NaN  ...     3.0    NaN     46.0   NaN
# 2020-03-14    NaN    1.0     2.0    NaN  ...     5.0    1.0     65.0   NaN
# 2020-03-15    NaN    1.0     2.0    NaN  ...     6.0    1.0     65.0   NaN
# 2020-03-16    NaN    1.0     2.0    NaN  ...     7.0    5.0    152.0   NaN
# 2020-03-17    3.0    1.0     2.0    NaN  ...     7.0    5.0    164.0   NaN
# 2020-03-18    3.0    1.0     2.0    NaN  ...    14.0    6.0    240.0   1.0
# 2020-03-19    4.0    4.0     3.0    NaN  ...    21.0    6.0    286.0   1.0
# 2020-03-20    7.0    6.0     7.0    1.0  ...    40.0    7.0    396.0   1.0
# 2020-03-21   11.0    7.0    11.0    1.0  ...    57.0   10.0    396.0   2.0
# 2020-03-22   11.0    7.0    26.0    1.0  ...    68.0   10.0    631.0   5.0
# 2020-03-23   17.0    8.0    32.0    1.0  ...    86.0   10.0    745.0   7.0
# 2020-03-24   21.0   10.0    47.0    1.0  ...   109.0   15.0    810.0   7.0
# 2020-03-25   23.0   11.0    54.0    2.0  ...   122.0   16.0    862.0   7.0
# 2020-03-26   23.0   11.0    67.0    2.0  ...   149.0   16.0   1052.0   8.0
# 2020-03-27   25.0   12.0    81.0    3.0  ...   163.0   16.0   1223.0   9.0
# 2020-03-28   25.0   14.0   111.0    4.0  ...   184.0   16.0   1406.0   9.0
# 2020-03-29   34.0   17.0   140.0    8.0  ...   197.0   16.0   1451.0  10.0
# 2020-03-30   41.0   17.0   151.0    8.0  ...   219.0   18.0   1517.0  11.0
# 2020-03-31   42.0   18.0   175.0   10.0  ...   235.0   19.0   2339.0  12.0
# 2020-04-01   43.0   18.0   200.0   11.0  ...   247.0   22.0   2981.0  12.0
# 2020-04-02   45.0   18.0   229.0   12.0  ...   281.0   24.0   3506.0  12.0
# 2020-04-03   46.0   23.0   260.0   19.0  ...   301.0   27.0   4048.0  13.0
# 2020-04-04   46.0   23.0   311.0   29.0  ...   356.0   32.0   4466.0  16.0
# 2020-04-05   48.0   28.0   417.0   32.0  ...   379.0   32.0   4620.0  17.0
# 2020-04-06   50.0   31.0   532.0   39.0  ...   417.0   32.0   4866.0  19.0
# 2020-04-07   50.0   34.0   636.0   51.0  ...   457.0   36.0   5682.0  19.0
# 2020-04-08   58.0   37.0   804.0  107.0  ...   501.0   39.0   6708.0  23.0
# 2020-04-09   62.0   37.0   899.0  110.0  ...   693.0   40.0   7480.0  23.0
# 2020-04-10   70.0   45.0   981.0  166.0  ...   717.0   42.0   8216.0  23.0
# 2020-04-11   72.0   48.0  1049.0  193.0  ...   732.0   44.0   8419.0  25.0
# 2020-04-12   77.0   48.0  1206.0  237.0  ...   776.0   44.0   8755.0  26.0
# 2020-04-13   90.0   58.0  1275.0  244.0  ...   826.0   45.0   8895.0  26.0
# 2020-04-14   99.0   72.0  1484.0  308.0  ...   853.0   46.0   9371.0  27.0
# 2020-04-15  101.0   83.0  1554.0  342.0  ...   884.0   48.0  11043.0  29.0
# 2020-04-16  115.0   89.0  1719.0  362.0  ...   926.0   53.0  11568.0  31.0
# 2020-04-17  135.0  110.0  1809.0  375.0  ...   962.0   58.0  12841.0  32.0
# 2020-04-18  142.0  132.0  1897.0  400.0  ...   975.0   71.0  13894.0  33.0
# 2020-04-19  163.0  159.0  2044.0  416.0  ...  1025.0   86.0  14267.0  34.0
# 2020-04-20  176.0  171.0  2160.0  435.0  ...  1063.0   92.0  14580.0  35.0
# 2020-04-21  195.0  210.0  2270.0  466.0  ...  1091.0  117.0  15385.0  36.0
# 2020-04-22  214.0  243.0  2479.0  492.0  ...  1115.0  118.0  15914.0  37.0
#
# [58 rows x 27 columns]

# %% [markdown]
# **Visualização de Dados**

# %%
# Visualizar número totais de caasos por estado
data_cases.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20)
plt.xlabel('Data', fontsize=20);
plt.ylabel('Número de casos confirmados', fontsize=20);
plt.title('COVID19 - Evoluçao de casos confirmados', fontsize=20);

# %%
# Visualizar número totais de casos por estado na escala semi-logarítmica
data_cases.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20, logy = True)
plt.xlabel('Data', fontsize=20);
plt.ylabel('Número de casos confirmados', fontsize=20);
plt.title('Evoluçao de casos confirmados pela COVID-19', fontsize=20);

# %% [markdown]
# # **Visualização de dados alinhando o primeiro dia com 5 casos**

# %%
# Iterar sobre as colunas e valores < 5 serão nulos
for col in data_cases.columns:
    data_cases.loc[(data_cases[col] < 5), col] = None

# Check out tail
data_cases.tail()
# Out:
# state          AC     AL      AM     AP  ...      SC     SE       SP    TO
# date                                     ...
# 2020-04-18  142.0  132.0  1897.0  400.0  ...   975.0   71.0  13894.0  33.0
# 2020-04-19  163.0  159.0  2044.0  416.0  ...  1025.0   86.0  14267.0  34.0
# 2020-04-20  176.0  171.0  2160.0  435.0  ...  1063.0   92.0  14580.0  35.0
# 2020-04-21  195.0  210.0  2270.0  466.0  ...  1091.0  117.0  15385.0  36.0
# 2020-04-22  214.0  243.0  2479.0  492.0  ...  1115.0  118.0  15914.0  37.0
#
# [5 rows x 27 columns]

# %%
# Retirar colunas que tenham tudo NaNs (estados que ainda não chegaram a 5 casos)
data_cases.dropna(axis = 1, how = "all", inplace = True)
data_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 58 entries, 2020-02-25 to 2020-04-22
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AC      34 non-null     float64
#  1   AL      34 non-null     float64
#  2   AM      34 non-null     float64
#  3   AP      25 non-null     float64
#  4   BA      41 non-null     float64
#  5   CE      38 non-null     float64
#  6   DF      40 non-null     float64
#  7   ES      38 non-null     float64
#  8   GO      38 non-null     float64
#  9   MA      31 non-null     float64
#  10  MG      38 non-null     float64
#  11  MS      37 non-null     float64
#  12  MT      31 non-null     float64
#  13  PA      31 non-null     float64
#  14  PB      29 non-null     float64
#  15  PE      40 non-null     float64
#  16  PI      32 non-null     float64
#  17  PR      42 non-null     float64
#  18  RJ      42 non-null     float64
#  19  RN      34 non-null     float64
#  20  RO      30 non-null     float64
#  21  RR      30 non-null     float64
#  22  RS      38 non-null     float64
#  23  SC      40 non-null     float64
#  24  SE      38 non-null     float64
#  25  SP      49 non-null     float64
#  26  TO      32 non-null     float64
# dtypes: float64(27)
# memory usage: 12.7 KB

# %%
# Criar dataframe com a data do primeiro dia com o 5o caso em cada estado
date_5th_cases = data_cases.apply(pd.Series.first_valid_index)
df_5th_cases = pd.DataFrame(date_5th_cases)
df_5th_cases
# Out:
#                0
# state
# AC    2020-03-20
# AL    2020-03-20
# AM    2020-03-20
# AP    2020-03-29
# BA    2020-03-13
# CE    2020-03-16
# DF    2020-03-14
# ES    2020-03-16
# GO    2020-03-16
# MA    2020-03-23
# MG    2020-03-16
# MS    2020-03-17
# MT    2020-03-23
# PA    2020-03-23
# PB    2020-03-25
# PE    2020-03-14
# PI    2020-03-22
# PR    2020-03-12
# RJ    2020-03-12
# RN    2020-03-20
# RO    2020-03-24
# RR    2020-03-24
# RS    2020-03-16
# SC    2020-03-14
# SE    2020-03-16
# SP    2020-03-05
# TO    2020-03-22

# %%
# Resetar o index, retirar a coluna de data
data_cases_drop = data_cases.reset_index().drop(['date'], axis = 1)
data_cases_drop.head()
# Out:
# state  AC  AL  AM  AP  BA  CE  DF  ES  GO  ...  RJ  RN  RO  RR  RS  SC  SE  SP  TO
# 0     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 27 columns]

# %%
# Trazer para cima os dados a partir do primeiro dado válido (shift)
for col in data_cases_drop.columns:
    data_cases_drop[col] = data_cases_drop[col].shift(-data_cases_drop[col].first_valid_index())
# check out head
data_cases_drop
# Out:
# state     AC     AL      AM     AP      BA  ...     RS      SC     SE       SP    TO
# 0        7.0    6.0     7.0    8.0     7.0  ...    8.0     5.0    5.0      6.0   5.0
# 1       11.0    7.0    11.0    8.0     7.0  ...    8.0     6.0    5.0     10.0   7.0
# 2       11.0    7.0    26.0   10.0     9.0  ...   19.0     7.0    6.0     13.0   7.0
# 3       17.0    8.0    32.0   11.0    10.0  ...   31.0     7.0    6.0     16.0   7.0
# 4       21.0   10.0    47.0   12.0    14.0  ...   43.0    14.0    7.0     16.0   8.0
# 5       23.0   11.0    54.0   19.0    27.0  ...   69.0    21.0   10.0     19.0   9.0
# 6       23.0   11.0    67.0   29.0    31.0  ...   77.0    40.0   10.0     30.0   9.0
# 7       25.0   12.0    81.0   32.0    34.0  ...   96.0    57.0   10.0     46.0  10.0
# 8       25.0   14.0   111.0   39.0    41.0  ...  112.0    68.0   15.0     46.0  11.0
# 9       34.0   17.0   140.0   51.0    55.0  ...  162.0    86.0   16.0     65.0  12.0
# 10      41.0   17.0   151.0  107.0    63.0  ...  190.0   109.0   16.0     65.0  12.0
# 11      42.0   18.0   175.0  110.0    79.0  ...  197.0   122.0   16.0    152.0  12.0
# 12      43.0   18.0   200.0  166.0    91.0  ...  200.0   149.0   16.0    164.0  13.0
# 13      45.0   18.0   229.0  193.0   108.0  ...  230.0   163.0   16.0    240.0  16.0
# 14      46.0   23.0   260.0  237.0   123.0  ...  254.0   184.0   18.0    286.0  17.0
# 15      46.0   23.0   311.0  244.0   127.0  ...  305.0   197.0   19.0    396.0  19.0
# 16      48.0   28.0   417.0  308.0   156.0  ...  316.0   219.0   22.0    396.0  19.0
# 17      50.0   31.0   532.0  342.0   176.0  ...  386.0   235.0   24.0    631.0  23.0
# 18      50.0   34.0   636.0  362.0   217.0  ...  410.0   247.0   27.0    745.0  23.0
# 19      58.0   37.0   804.0  375.0   246.0  ...  418.0   281.0   32.0    810.0  23.0
# 20      62.0   37.0   899.0  400.0   267.0  ...  468.0   301.0   32.0    862.0  25.0
# 21      70.0   45.0   981.0  416.0   290.0  ...  501.0   356.0   32.0   1052.0  26.0
# 22      72.0   48.0  1049.0  435.0   336.0  ...  555.0   379.0   36.0   1223.0  26.0
# 23      77.0   48.0  1206.0  466.0   401.0  ...  581.0   417.0   39.0   1406.0  27.0
# 24      90.0   58.0  1275.0  492.0   437.0  ...  636.0   457.0   40.0   1451.0  29.0
# 25      99.0   72.0  1484.0    NaN   462.0  ...  640.0   501.0   42.0   1517.0  31.0
# 26     101.0   83.0  1554.0    NaN   515.0  ...  653.0   693.0   44.0   2339.0  32.0
# 27     115.0   89.0  1719.0    NaN   568.0  ...  664.0   717.0   44.0   2981.0  33.0
# 28     135.0  110.0  1809.0    NaN   616.0  ...  685.0   732.0   45.0   3506.0  34.0
# 29     142.0  132.0  1897.0    NaN   640.0  ...  720.0   776.0   46.0   4048.0  35.0
# 30     163.0  159.0  2044.0    NaN   674.0  ...  762.0   826.0   48.0   4466.0  36.0
# 31     176.0  171.0  2160.0    NaN   723.0  ...  792.0   853.0   53.0   4620.0  37.0
# 32     195.0  210.0  2270.0    NaN   776.0  ...  831.0   884.0   58.0   4866.0   NaN
# 33     214.0  243.0  2479.0    NaN   884.0  ...  854.0   926.0   71.0   5682.0   NaN
# 34       NaN    NaN     NaN    NaN   967.0  ...  869.0   962.0   86.0   6708.0   NaN
# 35       NaN    NaN     NaN    NaN  1064.0  ...  904.0   975.0   92.0   7480.0   NaN
# 36       NaN    NaN     NaN    NaN  1200.0  ...  918.0  1025.0  117.0   8216.0   NaN
# 37       NaN    NaN     NaN    NaN  1249.0  ...  970.0  1063.0  118.0   8419.0   NaN
# 38       NaN    NaN     NaN    NaN  1377.0  ...    NaN  1091.0    NaN   8755.0   NaN
# 39       NaN    NaN     NaN    NaN  1504.0  ...    NaN  1115.0    NaN   8895.0   NaN
# 40       NaN    NaN     NaN    NaN  1645.0  ...    NaN     NaN    NaN   9371.0   NaN
# 41       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  11043.0   NaN
# 42       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  11568.0   NaN
# 43       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  12841.0   NaN
# 44       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  13894.0   NaN
# 45       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  14267.0   NaN
# 46       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  14580.0   NaN
# 47       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  15385.0   NaN
# 48       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN  15914.0   NaN
# 49       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 50       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 51       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 52       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 53       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 54       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 55       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 56       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
# 57       NaN    NaN     NaN    NaN     NaN  ...    NaN     NaN    NaN      NaN   NaN
#
# [58 rows x 27 columns]

# %%
# Evolução na escala semi-logarítimica 
data_cases_drop.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20, logy = True)
plt.xlabel('Dias', fontsize=20);
plt.ylabel('Número de Casos Confirmados', fontsize=20);
plt.title('Total de casos confirmados nos estados (a partir de 5 casos)', fontsize=20);

# %% [markdown]
# # **Visualização interativa com Altair**

# %%
# Transformar dados em long para utilizar no altair
# Endereço da Biblioteca: https://matthewkudija.com/blog/2018/06/22/altair-interactive/
cases_long = data_cases_drop.reset_index().melt(id_vars = 'index', value_name = 'confirmed').rename(columns={'index':'Day'})
cases_long
# Out:
#       Day state  confirmed
# 0       0    AC        7.0
# 1       1    AC       11.0
# 2       2    AC       11.0
# 3       3    AC       17.0
# 4       4    AC       21.0
# ...   ...   ...        ...
# 1561   53    TO        NaN
# 1562   54    TO        NaN
# 1563   55    TO        NaN
# 1564   56    TO        NaN
# 1565   57    TO        NaN
#
# [1566 rows x 3 columns]

# %%
# Adicionar primeiro dia da 5a morte por estado
cases_long = cases_long.merge(df_5th_cases, left_on='state', right_index=True, how='left')
cases_long
# Out:
#       Day state  confirmed          0
# 0       0    AC        7.0 2020-03-20
# 1       1    AC       11.0 2020-03-20
# 2       2    AC       11.0 2020-03-20
# 3       3    AC       17.0 2020-03-20
# 4       4    AC       21.0 2020-03-20
# ...   ...   ...        ...        ...
# 1561   53    TO        NaN 2020-03-22
# 1562   54    TO        NaN 2020-03-22
# 1563   55    TO        NaN 2020-03-22
# 1564   56    TO        NaN 2020-03-22
# 1565   57    TO        NaN 2020-03-22
#
# [1566 rows x 4 columns]

# %%
# Adicionar coluna com a data de cada observação
from datetime import datetime  
from datetime import timedelta 
cases_long['Date'] = cases_long.iloc[:,3] + cases_long['Day'].map(timedelta)
cases_long
# Out:
#       Day state  confirmed          0       Date
# 0       0    AC        7.0 2020-03-20 2020-03-20
# 1       1    AC       11.0 2020-03-20 2020-03-21
# 2       2    AC       11.0 2020-03-20 2020-03-22
# 3       3    AC       17.0 2020-03-20 2020-03-23
# 4       4    AC       21.0 2020-03-20 2020-03-24
# ...   ...   ...        ...        ...        ...
# 1561   53    TO        NaN 2020-03-22 2020-05-14
# 1562   54    TO        NaN 2020-03-22 2020-05-15
# 1563   55    TO        NaN 2020-03-22 2020-05-16
# 1564   56    TO        NaN 2020-03-22 2020-05-17
# 1565   57    TO        NaN 2020-03-22 2020-05-18
#
# [1566 rows x 5 columns]

# %%
# Remover coluna com primeiro dia da 5a morte
cases_long = cases_long.drop([cases_long.columns[3]] ,  axis='columns')
cases_long
# Out:
#       Day state  confirmed       Date
# 0       0    AC        7.0 2020-03-20
# 1       1    AC       11.0 2020-03-21
# 2       2    AC       11.0 2020-03-22
# 3       3    AC       17.0 2020-03-23
# 4       4    AC       21.0 2020-03-24
# ...   ...   ...        ...        ...
# 1561   53    TO        NaN 2020-05-14
# 1562   54    TO        NaN 2020-05-15
# 1563   55    TO        NaN 2020-05-16
# 1564   56    TO        NaN 2020-05-17
# 1565   57    TO        NaN 2020-05-18
#
# [1566 rows x 4 columns]

# %%
# Adicionar população por estado
cases_long = cases_long.merge(states_pop, left_on='state', right_index=True, how='left')
cases_long.head()
# Out:
#    Day state  confirmed       Date  estimated_population_2019
# 0    0    AC        7.0 2020-03-20                   881935.0
# 1    1    AC       11.0 2020-03-21                   881935.0
# 2    2    AC       11.0 2020-03-22                   881935.0
# 3    3    AC       17.0 2020-03-23                   881935.0
# 4    4    AC       21.0 2020-03-24                   881935.0

# %%
# Adicionar taxa de casos a cada 100.000 habitantes
cases_long['CasesPop'] = cases_long['confirmed']/cases_long['estimated_population_2019']*100000
cases_long.head()
# Out:
#    Day state  confirmed       Date  estimated_population_2019  CasesPop
# 0    0    AC        7.0 2020-03-20                   881935.0  0.793709
# 1    1    AC       11.0 2020-03-21                   881935.0  1.247257
# 2    2    AC       11.0 2020-03-22                   881935.0  1.247257
# 3    3    AC       17.0 2020-03-23                   881935.0  1.927580
# 4    4    AC       21.0 2020-03-24                   881935.0  2.381128

# %%
# drop NaNs
cases_long = cases_long.dropna()
cases_long
# Out:
#       Day state  confirmed       Date  estimated_population_2019  CasesPop
# 0       0    AC        7.0 2020-03-20                   881935.0  0.793709
# 1       1    AC       11.0 2020-03-21                   881935.0  1.247257
# 2       2    AC       11.0 2020-03-22                   881935.0  1.247257
# 3       3    AC       17.0 2020-03-23                   881935.0  1.927580
# 4       4    AC       21.0 2020-03-24                   881935.0  2.381128
# ...   ...   ...        ...        ...                        ...       ...
# 1535   27    TO       33.0 2020-04-18                  1572866.0  2.098081
# 1536   28    TO       34.0 2020-04-19                  1572866.0  2.161659
# 1537   29    TO       35.0 2020-04-20                  1572866.0  2.225237
# 1538   30    TO       36.0 2020-04-21                  1572866.0  2.288815
# 1539   31    TO       37.0 2020-04-22                  1572866.0  2.352394
#
# [966 rows x 6 columns]

# %%
import altair as alt

# Selection tool
selection = alt.selection_single(fields=['state'])
# Color change when clicked
color = alt.condition(selection,
                    alt.Color('state:N'),
                    alt.value('lightgray'))


# Base altair plot 
base = alt.Chart(cases_long, title="COVID19 - Total de casos confirmados por estado brasileiro").mark_line(strokeWidth=4, opacity=0.7).encode(
    x=alt.X('Day'),
    y=alt.Y('confirmed', scale=alt.Scale(type='log')),
    color=alt.Color('state', legend=None),
).properties(
    width=650,
    height=800
)

# Chart
chart = base.encode(
  color=alt.condition(selection, 'state:N', alt.value('lightgray')),
  tooltip=['state:N', 'yearmonthdate(Date):N', 'confirmed:N']
).add_selection(
  selection
)

# Overlay
overlay = base.encode(
  color='state',
  opacity=alt.value(0.5),
).transform_filter(
  selection
)

# Text labels
text = base.mark_text(
    align='left',
    dx=5,
    size=15
).encode(
    x=alt.X('Day', aggregate='max',  axis=alt.Axis(title='Dias a partir do 5o. caso no estado')),
    y=alt.Y('confirmed', aggregate={'argmax': 'Day'}, axis=alt.Axis(title='Casos confirmados (escala logarítmica)')),
    text='state'
).transform_filter(
    selection
)

# Add doubling line

## Death doubles every 2 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/2)) < cases_long.confirmed.max():
      j = i+2

source2 = alt.sequence(start=0, stop=j, step=1, as_='x')

double2 = alt.Chart(source2).mark_line(strokeDash=[2,2]).transform_calculate(
    double2='5*pow(2,(datum.x/2))'
).transform_fold(
    ['double2']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text2 = alt.Chart({'values':[{'x': 13, 'y': 500}]}).mark_text(
    text='casos duplicam a cada 2 dias', angle=305,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

## Cases doubles every 5 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/5)) < cases_long.confirmed.max():
      j = i+2

source5 = alt.sequence(start=0, stop=j, step=1, as_='x')

double5 = alt.Chart(source5).mark_line(strokeDash=[2,2]).transform_calculate(
    double5='5*pow(2,(datum.x/5))'
).transform_fold(
    ['double5']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text5 = alt.Chart({'values':[{'x': 24, 'y': 150}]}).mark_text(
    text='a cada 5 dias', angle=329,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

## Cases doubles every 10 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/10)) < cases_long.confirmed.max():
      j = i+2

source10 = alt.sequence(start=0, stop=j, step=1, as_='x')

double10 = alt.Chart(source10).mark_line(strokeDash=[2,2]).transform_calculate(
    double10='5*pow(2,(datum.x/10))'
).transform_fold(
    ['double10']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text10 = alt.Chart({'values':[{'x': 24, 'y': 28}]}).mark_text(
    text='a cada 10 dias', angle=343,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

# Sum it all up
alt.layer(chart, overlay, text, double2, double5, double10, text2, text5, text10).configure_axis(
    labelFontSize=15,
    titleFontSize=20
).configure_title(
    fontSize=23
)


# Sum em up!
#chart + overlay + text
# Out:
# alt.LayerChart(...)

# %%
# Mortes por habitantes

# Base altair plot 
basepop = alt.Chart(cases_long, title="COVID19 - Casos confirmados a cada 100 mil habitantes").mark_line(strokeWidth=4, opacity=0.7).encode(
    x=alt.X('Day'),
    y=alt.Y('confirmed'),
    color=alt.Color('state', legend=None),
).properties(
    width=650,
    height=800
)

# Chart
chartpop = basepop.encode(
  color=alt.condition(selection, 'state:N', alt.value('lightgray')),
  tooltip=['state:N', 'yearmonthdate(Date):N', 'confirmed:N']
).add_selection(
  selection
)

# Overlay
overlaypop = basepop.encode(
  color='state',
  opacity=alt.value(0.5),
).transform_filter(
  selection
)

# Text labels
textpop = basepop.mark_text(
    align='left',
    dx=5,
    size=15
).encode(
    x=alt.X('Day', aggregate='max',  axis=alt.Axis(title='Dias a partir do 5. caso no estado')),
    y=alt.Y('confirmed', aggregate={'argmax': 'Day'}, axis=alt.Axis(title='Casos confirmados a cada 100 mil habitantes')),
    text='state'
).transform_filter(
    selection
)

# Sum em up!
alt.layer(chartpop + overlaypop + textpop).configure_axis(
    labelFontSize=15,
    titleFontSize=20
).configure_title(
    fontSize=23
)
# Out:
# alt.LayerChart(...)
