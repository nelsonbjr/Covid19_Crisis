# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsonbjr/Covid19_Crisis/blob/master/covid19_Brasil_02APR20_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **OBTENDO DADOS E PREPARANDO O AMBIENTE**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.tail()
# Out:
#                Province/State  Country/Region  ...  3/31/20  4/1/20
# 251  Turks and Caicos Islands  United Kingdom  ...        5       6
# 252                       NaN      MS Zaandam  ...        2       9
# 253                       NaN        Botswana  ...        4       4
# 254                       NaN         Burundi  ...        2       2
# 255                       NaN    Sierra Leone  ...        1       2
#
# [5 rows x 75 columns]

# %%
casos.rename(columns={'Country/Region' : 'Country'}, inplace = True)
casos.tail()
# Out:
#                Province/State         Country  ...  3/31/20  4/1/20
# 251  Turks and Caicos Islands  United Kingdom  ...        5       6
# 252                       NaN      MS Zaandam  ...        2       9
# 253                       NaN        Botswana  ...        4       4
# 254                       NaN         Burundi  ...        2       2
# 255                       NaN    Sierra Leone  ...        1       2
#
# [5 rows x 75 columns]

# %% [markdown]
# ## **SELECIONANDO DADOS DO BRASIL**

# %%
casos_BR = casos[casos.Country == "Brazil"]
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/29/20  3/30/20  3/31/20  4/1/20
# 28            NaN  Brazil -14.235 -51.9253  ...     4256     4579     5717    6836
#
# [1 rows x 75 columns]

# %%
filtro_brasil = casos["Country"] == "Brazil"
casos.loc[filtro_brasil]
# Out:
#    Province/State Country     Lat     Long  ...  3/29/20  3/30/20  3/31/20  4/1/20
# 28            NaN  Brazil -14.235 -51.9253  ...     4256     4579     5717    6836
#
# [1 rows x 75 columns]

# %%
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/29/20  3/30/20  3/31/20  4/1/20
# 28            NaN  Brazil -14.235 -51.9253  ...     4256     4579     5717    6836
#
# [1 rows x 75 columns]

# %%
casos_BR = np.sum(casos_BR.iloc[ : , 4 : casos_BR.shape[1]]) ##Criando um índice atravez do atributo de data
casos_BR.index = pd.DatetimeIndex(casos_BR.index)
casos_BR.tail()
# Out:
# 2020-03-28    3904
# 2020-03-29    4256
# 2020-03-30    4579
# 2020-03-31    5717
# 2020-04-01    6836
# dtype: int64

# %%
casos_BR.plot() ##Gráfico com o número de casos do Brasil
plt.title('Numero de Casos - Brasil')
plt.show()

# %% [markdown]
# ## **MORTES POR COVID-19 NO BRASIL**

# %%
mortes = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
mortes.tail()
# Out:
#                Province/State  Country/Region  ...  3/31/20  4/1/20
# 251  Turks and Caicos Islands  United Kingdom  ...        0       0
# 252                       NaN      MS Zaandam  ...        0       2
# 253                       NaN        Botswana  ...        1       1
# 254                       NaN         Burundi  ...        0       0
# 255                       NaN    Sierra Leone  ...        0       0
#
# [5 rows x 75 columns]

# %%
mortes.rename(columns={'Country/Region' : 'Country'}, inplace = True)
mortes.tail()
# Out:
#                Province/State         Country  ...  3/31/20  4/1/20
# 251  Turks and Caicos Islands  United Kingdom  ...        0       0
# 252                       NaN      MS Zaandam  ...        0       2
# 253                       NaN        Botswana  ...        1       1
# 254                       NaN         Burundi  ...        0       0
# 255                       NaN    Sierra Leone  ...        0       0
#
# [5 rows x 75 columns]

# %%
mortes_BR = mortes[mortes.Country == "Brazil"] ## Selecionando os óbitos no Brasil
mortes_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/29/20  3/30/20  3/31/20  4/1/20
# 28            NaN  Brazil -14.235 -51.9253  ...      136      159      201     240
#
# [1 rows x 75 columns]

# %%
##Criando um índice atravez do atributo de data
mortes_BR = np.sum(mortes_BR.iloc[ : , 4 : mortes_BR.shape[1]])
mortes_BR.index = pd.DatetimeIndex(mortes_BR.index)
mortes_BR.tail()
# Out:
# 2020-03-28    111
# 2020-03-29    136
# 2020-03-30    159
# 2020-03-31    201
# 2020-04-01    240
# dtype: int64

# %%
mortes_BR.plot() ##Gráfico com o número de mortes do Brasil
plt.title('Número de Óbitos - BR')
plt.show()

# %% [markdown]
# ## **MORTALIDADE NO BRASIL**

# %%
mortalidade_BR = (mortes_BR/casos_BR)*100
mortalidade_BR.tail()
# Out:
# 2020-03-28    2.843238
# 2020-03-29    3.195489
# 2020-03-30    3.472374
# 2020-03-31    3.515830
# 2020-04-01    3.510825
# dtype: float64

# %%
mortalidade_BR.plot()
plt.title('Taxa de Mortlidade - BR (%)')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES RECUPERADOS NO BRASIL**

# %%
recuperados = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
recuperados.shape
# Out:
# (242, 75)

# %%
recuperados.rename(columns={'Country/Region' : 'Country'}, inplace = True)
recuperados.tail()
# Out:
#                Province/State         Country  ...  3/31/20  4/1/20
# 237  Turks and Caicos Islands  United Kingdom  ...        0       0
# 238                       NaN      MS Zaandam  ...        0       0
# 239                       NaN        Botswana  ...        0       0
# 240                       NaN         Burundi  ...        0       0
# 241                       NaN    Sierra Leone  ...        0       0
#
# [5 rows x 75 columns]

# %%
recuperados_BR = recuperados[recuperados.Country == "Brazil"]
recuperados_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/29/20  3/30/20  3/31/20  4/1/20
# 29            NaN  Brazil -14.235 -51.9253  ...        6      120      127     127
#
# [1 rows x 75 columns]

# %%
##Criando um índice atravez do atributo de data
recuperados_BR = np.sum(recuperados_BR.iloc[ : , 4 : recuperados_BR.shape[1]])
recuperados_BR.index = pd.DatetimeIndex(recuperados_BR.index)
recuperados_BR.tail()
# Out:
# 2020-03-28      6
# 2020-03-29      6
# 2020-03-30    120
# 2020-03-31    127
# 2020-04-01    127
# dtype: int64

# %%
recuperados_BR.plot()
plt.title('Pacientes Recuperados - Brasil')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES ATIVOS NO BRASIL**

# %%
ativos_BR = casos_BR - (recuperados_BR+mortes_BR)
ativos_BR.tail()
# Out:
# 2020-03-28    3787
# 2020-03-29    4114
# 2020-03-30    4300
# 2020-03-31    5389
# 2020-04-01    6469
# dtype: int64

# %%
ativos_BR.plot()

# %%
df = pd.concat([casos_BR, ativos_BR, recuperados_BR, mortes_BR], axis=1)
df.tail()
# Out:
#                0     1    2    3
# 2020-03-28  3904  3787    6  111
# 2020-03-29  4256  4114    6  136
# 2020-03-30  4579  4300  120  159
# 2020-03-31  5717  5389  127  201
# 2020-04-01  6836  6469  127  240

# %%
df.columns = (["casos", "ativos", "recuperados", "mortes"])
df.tail()
# Out:
#             casos  ativos  recuperados  mortes
# 2020-03-28   3904    3787            6     111
# 2020-03-29   4256    4114            6     136
# 2020-03-30   4579    4300          120     159
# 2020-03-31   5717    5389          127     201
# 2020-04-01   6836    6469          127     240

# %%
df.plot()

# %% [markdown]
# ## **CALCULANDO O NÚMERO DE NOVOS CASOS NO BRASIL**

# %%
## O objetivo desta análise é calcular a taxa de crescimento da Covid19 no Brasil
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

df.drop(["Province/State", "Lat", "Long"], axis=1, inplace=True)

brasil = df.loc[df["Country/Region"] == "Brazil"].copy()
brasil.reset_index(drop=True, inplace=True)

brasil_t = brasil.T
brasil_t.drop("Country/Region", inplace=True)
brasil_t.columns = ["Casos"]
brasil_t.index.name = "Data"
brasil_t.index = pd.to_datetime(brasil_t.index)
brasil_t["Novos Casos"] = brasil_t["Casos"].diff()
brasil_t.tail(30)
# Out:
#            Casos Novos Casos
# Data
# 2020-03-03     2           0
# 2020-03-04     4           2
# 2020-03-05     4           0
# 2020-03-06    13           9
# 2020-03-07    13           0
# 2020-03-08    20           7
# 2020-03-09    25           5
# 2020-03-10    31           6
# 2020-03-11    38           7
# 2020-03-12    52          14
# 2020-03-13   151          99
# 2020-03-14   151           0
# 2020-03-15   162          11
# 2020-03-16   200          38
# 2020-03-17   321         121
# 2020-03-18   372          51
# 2020-03-19   621         249
# 2020-03-20   793         172
# 2020-03-21  1021         228
# 2020-03-22  1546         525
# 2020-03-23  1924         378
# 2020-03-24  2247         323
# 2020-03-25  2554         307
# 2020-03-26  2985         431
# 2020-03-27  3417         432
# 2020-03-28  3904         487
# 2020-03-29  4256         352
# 2020-03-30  4579         323
# 2020-03-31  5717        1138
# 2020-04-01  6836        1119

# %%
brasil_t.plot()

# %% [markdown]
# ## **CALCULANDO A TAXA DE CRESCIMENTO NO BRASIL**

# %%
novos_casos = brasil_t["Casos"].diff()
novos_casos.tail()
# Out:
# Data
# 2020-03-28     487
# 2020-03-29     352
# 2020-03-30     323
# 2020-03-31    1138
# 2020-04-01    1119
# Name: Casos, dtype: object

# %%
df = pd.concat([casos_BR, novos_casos], axis=1)
df.tail()
# Out:
#                0 Casos
# 2020-03-28  3904   487
# 2020-03-29  4256   352
# 2020-03-30  4579   323
# 2020-03-31  5717  1138
# 2020-04-01  6836  1119

# %%
df.columns = (["casos", "Novos Casos"])
df.tail()
# Out:
#             casos Novos Casos
# 2020-03-28   3904         487
# 2020-03-29   4256         352
# 2020-03-30   4579         323
# 2020-03-31   5717        1138
# 2020-04-01   6836        1119

# %%
crescimento = (novos_casos[35:]/casos_BR[35:])*100
crescimento.tail(30)
# Out:
# Data
# 2020-03-03          0
# 2020-03-04         50
# 2020-03-05          0
# 2020-03-06    69.2308
# 2020-03-07          0
# 2020-03-08         35
# 2020-03-09         20
# 2020-03-10    19.3548
# 2020-03-11    18.4211
# 2020-03-12    26.9231
# 2020-03-13    65.5629
# 2020-03-14          0
# 2020-03-15    6.79012
# 2020-03-16         19
# 2020-03-17    37.6947
# 2020-03-18    13.7097
# 2020-03-19    40.0966
# 2020-03-20    21.6898
# 2020-03-21     22.331
# 2020-03-22    33.9586
# 2020-03-23    19.6466
# 2020-03-24    14.3747
# 2020-03-25    12.0204
# 2020-03-26    14.4389
# 2020-03-27    12.6427
# 2020-03-28    12.4744
# 2020-03-29    8.27068
# 2020-03-30    7.05394
# 2020-03-31    19.9055
# 2020-04-01    16.3692
# dtype: object

# %%
crescimento.plot()
plt.title('Taxa de Crescimento Diario (%)')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (11,7)
# %matplotlib inline
