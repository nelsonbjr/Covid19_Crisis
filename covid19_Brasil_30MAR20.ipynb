# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsonbjr/Covid19_Crisis/blob/master/covid19_Brasil_30MAR20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **OBTENDO DADOS E PREPARANDO O AMBIENTE**

# %%
import pandas as pd
import numpy as np
casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.tail()
# Out:
#                Province/State  Country/Region  ...  3/28/20  3/29/20
# 248                       NaN           Burma  ...        8       10
# 249                  Anguilla  United Kingdom  ...        2        2
# 250    British Virgin Islands  United Kingdom  ...        2        2
# 251  Turks and Caicos Islands  United Kingdom  ...        4        4
# 252                       NaN      MS Zaandam  ...        2        2
#
# [5 rows x 72 columns]

# %%
casos.rename(columns={'Country/Region' : 'Country'}, inplace = True)
casos.tail()
# Out:
#                Province/State         Country  ...  3/28/20  3/29/20
# 248                       NaN           Burma  ...        8       10
# 249                  Anguilla  United Kingdom  ...        2        2
# 250    British Virgin Islands  United Kingdom  ...        2        2
# 251  Turks and Caicos Islands  United Kingdom  ...        4        4
# 252                       NaN      MS Zaandam  ...        2        2
#
# [5 rows x 72 columns]

# %% [markdown]
# ## **SELECIONANDO DADOS DO BRASIL**

# %%
casos_BR = casos[casos.Country == "Brazil"]
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/26/20  3/27/20  3/28/20  3/29/20
# 28            NaN  Brazil -14.235 -51.9253  ...     2985     3417     3904     4256
#
# [1 rows x 72 columns]

# %%
filtro_brasil = casos["Country"] == "Brazil"
casos.loc[filtro_brasil]
# Out:
#    Province/State Country     Lat     Long  ...  3/26/20  3/27/20  3/28/20  3/29/20
# 28            NaN  Brazil -14.235 -51.9253  ...     2985     3417     3904     4256
#
# [1 rows x 72 columns]

# %%
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/26/20  3/27/20  3/28/20  3/29/20
# 28            NaN  Brazil -14.235 -51.9253  ...     2985     3417     3904     4256
#
# [1 rows x 72 columns]

# %%
casos_BR = np.sum(casos_BR.iloc[ : , 4 : casos_BR.shape[1]]) ##Criando um índice atravez do atributo de data
casos_BR.index = pd.DatetimeIndex(casos_BR.index)
casos_BR.tail()
# Out:
# 2020-03-25    2554
# 2020-03-26    2985
# 2020-03-27    3417
# 2020-03-28    3904
# 2020-03-29    4256
# dtype: int64

# %%
casos_BR.plot() ##Gráfico com o número de casos do Brasil

# %% [markdown]
# ## **MORTES POR COVID-19 NO BRASIL**

# %%
mortes = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
mortes.tail()
# Out:
#                Province/State  Country/Region  ...  3/28/20  3/29/20
# 248                       NaN           Burma  ...        0        0
# 249                  Anguilla  United Kingdom  ...        0        0
# 250    British Virgin Islands  United Kingdom  ...        0        0
# 251  Turks and Caicos Islands  United Kingdom  ...        0        0
# 252                       NaN      MS Zaandam  ...        0        0
#
# [5 rows x 72 columns]

# %%
mortes.rename(columns={'Country/Region' : 'Country'}, inplace = True)
mortes.tail()
# Out:
#                Province/State         Country  ...  3/28/20  3/29/20
# 248                       NaN           Burma  ...        0        0
# 249                  Anguilla  United Kingdom  ...        0        0
# 250    British Virgin Islands  United Kingdom  ...        0        0
# 251  Turks and Caicos Islands  United Kingdom  ...        0        0
# 252                       NaN      MS Zaandam  ...        0        0
#
# [5 rows x 72 columns]

# %%
mortes_BR = mortes[mortes.Country == "Brazil"] ## Selecionando os óbitos no Brasil
mortes_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/26/20  3/27/20  3/28/20  3/29/20
# 28            NaN  Brazil -14.235 -51.9253  ...       77       92      111      136
#
# [1 rows x 72 columns]

# %%
##Criando um índice atravez do atributo de data
mortes_BR = np.sum(mortes_BR.iloc[ : , 4 : mortes_BR.shape[1]])
mortes_BR.index = pd.DatetimeIndex(mortes_BR.index)
mortes_BR.tail()
# Out:
# 2020-03-25     59
# 2020-03-26     77
# 2020-03-27     92
# 2020-03-28    111
# 2020-03-29    136
# dtype: int64

# %%
mortes_BR.plot() ##Gráfico com o número de mortes do Brasil

# %% [markdown]
# ## **MORTALIDADE NO BRASIL**

# %%
mortalidade_BR = (mortes_BR/casos_BR)*100
mortalidade_BR.tail()
# Out:
# 2020-03-25    2.310102
# 2020-03-26    2.579564
# 2020-03-27    2.692420
# 2020-03-28    2.843238
# 2020-03-29    3.195489
# dtype: float64

# %%
mortalidade_BR.plot()

# %% [markdown]
# ## **DADOS DE PACIENTES RECUPERADOS NO BRASIL**

# %%
recuperados = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
recuperados.shape
# Out:
# (239, 72)

# %%
recuperados.rename(columns={'Country/Region' : 'Country'}, inplace = True)
recuperados.tail()
# Out:
#                Province/State         Country  ...  3/28/20  3/29/20
# 234                       NaN           Burma  ...        0        0
# 235                  Anguilla  United Kingdom  ...        0        0
# 236    British Virgin Islands  United Kingdom  ...        0        0
# 237  Turks and Caicos Islands  United Kingdom  ...        0        0
# 238                       NaN      MS Zaandam  ...        0        0
#
# [5 rows x 72 columns]

# %%
recuperados_BR = recuperados[recuperados.Country == "Brazil"]
recuperados_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  3/26/20  3/27/20  3/28/20  3/29/20
# 29            NaN  Brazil -14.235 -51.9253  ...        6        6        6        6
#
# [1 rows x 72 columns]

# %%
##Criando um índice atravez do atributo de data
recuperados_BR = np.sum(recuperados_BR.iloc[ : , 4 : recuperados_BR.shape[1]])
recuperados_BR.index = pd.DatetimeIndex(recuperados_BR.index)
recuperados_BR.tail()
# Out:
# 2020-03-25    2
# 2020-03-26    6
# 2020-03-27    6
# 2020-03-28    6
# 2020-03-29    6
# dtype: int64

# %%
recuperados_BR.plot()

# %% [markdown]
# ## **DADOS DE PACIENTES ATIVOS NO BRASIL**

# %%
ativos_BR = casos_BR - (recuperados_BR+mortes_BR)
ativos_BR.tail()
# Out:
# 2020-03-25    2493
# 2020-03-26    2902
# 2020-03-27    3319
# 2020-03-28    3787
# 2020-03-29    4114
# dtype: int64

# %%
ativos_BR.plot()

# %%
df = pd.concat([casos_BR, ativos_BR, recuperados_BR, mortes_BR], axis=1)
df.tail()
# Out:
#                0     1  2    3
# 2020-03-25  2554  2493  2   59
# 2020-03-26  2985  2902  6   77
# 2020-03-27  3417  3319  6   92
# 2020-03-28  3904  3787  6  111
# 2020-03-29  4256  4114  6  136

# %%
df.columns = (["casos", "ativos", "recuperados", "mortes"])
df.tail()
# Out:
#             casos  ativos  recuperados  mortes
# 2020-03-25   2554    2493            2      59
# 2020-03-26   2985    2902            6      77
# 2020-03-27   3417    3319            6      92
# 2020-03-28   3904    3787            6     111
# 2020-03-29   4256    4114            6     136

# %%
df.plot()

# %% [markdown]
# ## **CALCULANDO O NÚMERO DE NOVOS CASOS NO BRASIL**

# %%
## O objetivo desta análise é calcular a taxa de crescimento da Covid19 no Brasil
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

df.drop(["Province/State", "Lat", "Long"], axis=1, inplace=True)

brasil = df.loc[df["Country/Region"] == "Brazil"].copy()
brasil.reset_index(drop=True, inplace=True)

brasil_t = brasil.T
brasil_t.drop("Country/Region", inplace=True)
brasil_t.columns = ["Casos"]
brasil_t.index.name = "Data"
brasil_t.index = pd.to_datetime(brasil_t.index)
brasil_t["Novos Casos"] = brasil_t["Casos"].diff()
brasil_t.tail(30)
# Out:
#            Casos Novos Casos
# Data
# 2020-02-29     2           1
# 2020-03-01     2           0
# 2020-03-02     2           0
# 2020-03-03     2           0
# 2020-03-04     4           2
# 2020-03-05     4           0
# 2020-03-06    13           9
# 2020-03-07    13           0
# 2020-03-08    20           7
# 2020-03-09    25           5
# 2020-03-10    31           6
# 2020-03-11    38           7
# 2020-03-12    52          14
# 2020-03-13   151          99
# 2020-03-14   151           0
# 2020-03-15   162          11
# 2020-03-16   200          38
# 2020-03-17   321         121
# 2020-03-18   372          51
# 2020-03-19   621         249
# 2020-03-20   793         172
# 2020-03-21  1021         228
# 2020-03-22  1546         525
# 2020-03-23  1924         378
# 2020-03-24  2247         323
# 2020-03-25  2554         307
# 2020-03-26  2985         431
# 2020-03-27  3417         432
# 2020-03-28  3904         487
# 2020-03-29  4256         352

# %%
brasil_t.plot()

# %% [markdown]
# ## **CALCULANDO A TAXA DE CRESCIMENTO NO BRASIL**

# %%
novos_casos = brasil_t["Casos"].diff()
novos_casos.tail()
# Out:
# Data
# 2020-03-25    307
# 2020-03-26    431
# 2020-03-27    432
# 2020-03-28    487
# 2020-03-29    352
# Name: Casos, dtype: object

# %%
df = pd.concat([casos_BR, novos_casos], axis=1)
df.tail()
# Out:
#                0 Casos
# 2020-03-25  2554   307
# 2020-03-26  2985   431
# 2020-03-27  3417   432
# 2020-03-28  3904   487
# 2020-03-29  4256   352

# %%
df.columns = (["casos", "Novos Casos"])
df.tail()
# Out:
#             casos Novos Casos
# 2020-03-25   2554         307
# 2020-03-26   2985         431
# 2020-03-27   3417         432
# 2020-03-28   3904         487
# 2020-03-29   4256         352

# %%
crescimento = (novos_casos/casos_BR)*100
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-53-dd7ef93af50b> in <module>()
# ----> 1 crescimento = (novos_casos/casos_BR)*100
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     966
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#     970             result = masked_arith_op(x, y, op)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ZeroDivisionError: float division by zero
