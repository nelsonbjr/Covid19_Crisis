# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsonbjr/Covid19_Crisis/blob/master/covid19_Brasil_08MAI20_Novos_Graficos_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Autor: Nelson Biagio Junior
## Data: 21 MAR 2020

# %% [markdown]
# ## **OBTENDO DADOS E PREPARANDO O AMBIENTE**

# %%
# Importando Bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Set style & figures inline
sns.set()
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
casos = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
casos.tail()
# Out:
#     Province/State         Country/Region        Lat  ...  5/5/20  5/6/20  5/7/20
# 261            NaN         Western Sahara  24.215500  ...       6       6       6
# 262            NaN  Sao Tome and Principe   0.186360  ...     174     174     187
# 263            NaN                  Yemen  15.552727  ...      22      25      25
# 264            NaN                Comoros -11.645500  ...       3       8       8
# 265            NaN             Tajikistan  38.861034  ...     293     379     461
#
# [5 rows x 111 columns]

# %%
casos.rename(columns={'Country/Region' : 'Country'}, inplace = True)
casos.tail()
# Out:
#     Province/State                Country        Lat  ...  5/5/20  5/6/20  5/7/20
# 261            NaN         Western Sahara  24.215500  ...       6       6       6
# 262            NaN  Sao Tome and Principe   0.186360  ...     174     174     187
# 263            NaN                  Yemen  15.552727  ...      22      25      25
# 264            NaN                Comoros -11.645500  ...       3       8       8
# 265            NaN             Tajikistan  38.861034  ...     293     379     461
#
# [5 rows x 111 columns]

# %% [markdown]
# ## **SELECIONANDO DADOS DO BRASIL**

# %%
casos_BR = casos[casos.Country == "Brazil"]
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  5/4/20  5/5/20  5/6/20  5/7/20
# 28            NaN  Brazil -14.235 -51.9253  ...  108620  115455  126611  135773
#
# [1 rows x 111 columns]

# %%
filtro_brasil = casos["Country"] == "Brazil"
casos.loc[filtro_brasil]
# Out:
#    Province/State Country     Lat     Long  ...  5/4/20  5/5/20  5/6/20  5/7/20
# 28            NaN  Brazil -14.235 -51.9253  ...  108620  115455  126611  135773
#
# [1 rows x 111 columns]

# %%
casos_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  5/4/20  5/5/20  5/6/20  5/7/20
# 28            NaN  Brazil -14.235 -51.9253  ...  108620  115455  126611  135773
#
# [1 rows x 111 columns]

# %%
casos_BR = np.sum(casos_BR.iloc[ : , 4 : casos_BR.shape[1]]) ##Criando um índice atravez do atributo de data
casos_BR.index = pd.DatetimeIndex(casos_BR.index)
casos_BR.tail()
# Out:
# 2020-05-03    101826
# 2020-05-04    108620
# 2020-05-05    115455
# 2020-05-06    126611
# 2020-05-07    135773
# dtype: int64

# %%
casos_BR.plot() ##Gráfico com o número de casos do Brasil
plt.title('Numero de Casos - Brasil')
plt.show()

# %% [markdown]
# ## **MORTES POR COVID-19 NO BRASIL**

# %%
mortes = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
mortes.tail()
# Out:
#     Province/State         Country/Region        Lat  ...  5/5/20  5/6/20  5/7/20
# 261            NaN         Western Sahara  24.215500  ...       0       0       0
# 262            NaN  Sao Tome and Principe   0.186360  ...       3       3       4
# 263            NaN                  Yemen  15.552727  ...       4       5       5
# 264            NaN                Comoros -11.645500  ...       0       1       1
# 265            NaN             Tajikistan  38.861034  ...       5       8      12
#
# [5 rows x 111 columns]

# %%
mortes.rename(columns={'Country/Region' : 'Country'}, inplace = True)
mortes.tail()
# Out:
#     Province/State                Country        Lat  ...  5/5/20  5/6/20  5/7/20
# 261            NaN         Western Sahara  24.215500  ...       0       0       0
# 262            NaN  Sao Tome and Principe   0.186360  ...       3       3       4
# 263            NaN                  Yemen  15.552727  ...       4       5       5
# 264            NaN                Comoros -11.645500  ...       0       1       1
# 265            NaN             Tajikistan  38.861034  ...       5       8      12
#
# [5 rows x 111 columns]

# %%
mortes_BR = mortes[mortes.Country == "Brazil"] ## Selecionando os óbitos no Brasil
mortes_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  5/4/20  5/5/20  5/6/20  5/7/20
# 28            NaN  Brazil -14.235 -51.9253  ...    7367    7938    8588    9190
#
# [1 rows x 111 columns]

# %%
##Criando um índice atravez do atributo de data
mortes_BR = np.sum(mortes_BR.iloc[ : , 4 : mortes_BR.shape[1]])
mortes_BR.index = pd.DatetimeIndex(mortes_BR.index)
mortes_BR.tail()
# Out:
# 2020-05-03    7051
# 2020-05-04    7367
# 2020-05-05    7938
# 2020-05-06    8588
# 2020-05-07    9190
# dtype: int64

# %%
mortes_BR.plot() ##Gráfico com o número de mortes do Brasil
plt.title('Número de Óbitos - BR')
plt.show()

# %% [markdown]
# ## **MORTALIDADE NO BRASIL**

# %%
mortalidade_BR = (mortes_BR/casos_BR)*100
mortalidade_BR.tail(20)
# Out:
# 2020-04-18    6.421518
# 2020-04-19    6.369328
# 2020-04-20    6.349557
# 2020-04-21    6.362729
# 2020-04-22    6.350941
# 2020-04-23    6.657207
# 2020-04-24    6.853802
# 2020-04-25    6.838716
# 2020-04-26    6.792393
# 2020-04-27    6.824719
# 2020-04-28    6.940670
# 2020-04-29    6.918492
# 2020-04-30    6.888642
# 2020-05-01    6.954296
# 2020-05-02    6.962925
# 2020-05-03    6.924558
# 2020-05-04    6.782361
# 2020-05-05    6.875406
# 2020-05-06    6.782981
# 2020-05-07    6.768651
# dtype: float64

# %%
mortalidade_BR.plot()
plt.title('Taxa de Mortlidade - BR (%)')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES RECUPERADOS NO BRASIL**

# %%
recuperados = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
recuperados.shape
# Out:
# (252, 111)

# %%
recuperados.rename(columns={'Country/Region' : 'Country'}, inplace = True)
recuperados.tail()
# Out:
#     Province/State                Country        Lat  ...  5/5/20  5/6/20  5/7/20
# 247            NaN         Western Sahara  24.215500  ...       5       5       5
# 248            NaN  Sao Tome and Principe   0.186360  ...       4       4       4
# 249            NaN                  Yemen  15.552727  ...       1       1       1
# 250            NaN                Comoros -11.645500  ...       0       0       0
# 251            NaN             Tajikistan  38.861034  ...       0       0       0
#
# [5 rows x 111 columns]

# %%
recuperados_BR = recuperados[recuperados.Country == "Brazil"]
recuperados_BR.tail()
# Out:
#    Province/State Country     Lat     Long  ...  5/4/20  5/5/20  5/6/20  5/7/20
# 29            NaN  Brazil -14.235 -51.9253  ...   45815   48221   51370   55350
#
# [1 rows x 111 columns]

# %%
##Criando um índice atravez do atributo de data
recuperados_BR = np.sum(recuperados_BR.iloc[ : , 4 : recuperados_BR.shape[1]])
recuperados_BR.index = pd.DatetimeIndex(recuperados_BR.index)
recuperados_BR.tail()
# Out:
# 2020-05-03    42991
# 2020-05-04    45815
# 2020-05-05    48221
# 2020-05-06    51370
# 2020-05-07    55350
# dtype: int64

# %%
recuperados_BR.plot()
plt.title('Pacientes Recuperados - Brasil')
plt.show()

# %% [markdown]
# ## **DADOS DE PACIENTES ATIVOS NO BRASIL**

# %%
ativos_BR = casos_BR - (recuperados_BR+mortes_BR)
ativos_BR.tail()
# Out:
# 2020-05-03    51784
# 2020-05-04    55438
# 2020-05-05    59296
# 2020-05-06    66653
# 2020-05-07    71233
# dtype: int64

# %%
ativos_BR.plot()
plt.title('Pacientes Ativos - Brasil')
plt.show()

# %%
df = pd.concat([casos_BR, ativos_BR, recuperados_BR, mortes_BR], axis=1)
df.tail(80)
# Out:
#                  0      1      2     3
# 2020-02-18       0      0      0     0
# 2020-02-19       0      0      0     0
# 2020-02-20       0      0      0     0
# 2020-02-21       0      0      0     0
# 2020-02-22       0      0      0     0
# ...            ...    ...    ...   ...
# 2020-05-03  101826  51784  42991  7051
# 2020-05-04  108620  55438  45815  7367
# 2020-05-05  115455  59296  48221  7938
# 2020-05-06  126611  66653  51370  8588
# 2020-05-07  135773  71233  55350  9190
#
# [80 rows x 4 columns]

# %%
df.columns = (["casos", "ativos", "recuperados", "mortes"])
df.tail()
# Out:
#              casos  ativos  recuperados  mortes
# 2020-05-03  101826   51784        42991    7051
# 2020-05-04  108620   55438        45815    7367
# 2020-05-05  115455   59296        48221    7938
# 2020-05-06  126611   66653        51370    8588
# 2020-05-07  135773   71233        55350    9190

# %%
df.plot()
plt.title('Panorama Atual - Brasil')
plt.show()

# %% [markdown]
# ## **CALCULANDO O NÚMERO DE NOVOS CASOS NO BRASIL**

# %%
## O objetivo desta análise é calcular a taxa de crescimento da Covid19 no Brasil
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

df.drop(["Province/State", "Lat", "Long"], axis=1, inplace=True)

brasil = df.loc[df["Country/Region"] == "Brazil"].copy()
brasil.reset_index(drop=True, inplace=True)

brasil_t = brasil.T
brasil_t.drop("Country/Region", inplace=True)
brasil_t.columns = ["Casos"]
brasil_t.index.name = "Data"
brasil_t.index = pd.to_datetime(brasil_t.index)
brasil_t["Novos Casos"] = brasil_t["Casos"].diff()
brasil_t.tail(40)
# Out:
#              Casos Novos Casos
# Data
# 2020-03-29    4256         352
# 2020-03-30    4579         323
# 2020-03-31    5717        1138
# 2020-04-01    6836        1119
# 2020-04-02    8044        1208
# 2020-04-03    9056        1012
# 2020-04-04   10360        1304
# 2020-04-05   11130         770
# 2020-04-06   12161        1031
# 2020-04-07   14034        1873
# 2020-04-08   16170        2136
# 2020-04-09   18092        1922
# 2020-04-10   19638        1546
# 2020-04-11   20727        1089
# 2020-04-12   22192        1465
# 2020-04-13   23430        1238
# 2020-04-14   25262        1832
# 2020-04-15   28320        3058
# 2020-04-16   30425        2105
# 2020-04-17   33682        3257
# 2020-04-18   36658        2976
# 2020-04-19   38654        1996
# 2020-04-20   40743        2089
# 2020-04-21   43079        2336
# 2020-04-22   45757        2678
# 2020-04-23   50036        4279
# 2020-04-24   54043        4007
# 2020-04-25   59324        5281
# 2020-04-26   63100        3776
# 2020-04-27   67446        4346
# 2020-04-28   73235        5789
# 2020-04-29   79685        6450
# 2020-04-30   87187        7502
# 2020-05-01   92202        5015
# 2020-05-02   97100        4898
# 2020-05-03  101826        4726
# 2020-05-04  108620        6794
# 2020-05-05  115455        6835
# 2020-05-06  126611       11156
# 2020-05-07  135773        9162

# %%
brasil_t.plot()

# %% [markdown]
# ## **CALCULANDO A TAXA DE CRESCIMENTO NO BRASIL**

# %%
novos_casos = brasil_t["Casos"].diff()
novos_casos.tail()
# Out:
# Data
# 2020-05-03     4726
# 2020-05-04     6794
# 2020-05-05     6835
# 2020-05-06    11156
# 2020-05-07     9162
# Name: Casos, dtype: object

# %%
df = pd.concat([casos_BR, novos_casos], axis=1)
df.tail()
# Out:
#                  0  Casos
# 2020-05-03  101826   4726
# 2020-05-04  108620   6794
# 2020-05-05  115455   6835
# 2020-05-06  126611  11156
# 2020-05-07  135773   9162

# %%
df.columns = (["casos", "Novos Casos"])
df.tail()
# Out:
#              casos Novos Casos
# 2020-05-03  101826        4726
# 2020-05-04  108620        6794
# 2020-05-05  115455        6835
# 2020-05-06  126611       11156
# 2020-05-07  135773        9162

# %%
crescimento = (novos_casos[35:]/casos_BR[35:])*100
crescimento.tail(30)
# Out:
# Data
# 2020-04-08    13.2096
# 2020-04-09    10.6235
# 2020-04-10    7.87249
# 2020-04-11    5.25402
# 2020-04-12    6.60148
# 2020-04-13    5.28382
# 2020-04-14      7.252
# 2020-04-15     10.798
# 2020-04-16    6.91865
# 2020-04-17    9.66985
# 2020-04-18    8.11828
# 2020-04-19    5.16376
# 2020-04-20    5.12726
# 2020-04-21     5.4226
# 2020-04-22    5.85266
# 2020-04-23    8.55184
# 2020-04-24    7.41447
# 2020-04-25    8.90196
# 2020-04-26    5.98415
# 2020-04-27    6.44367
# 2020-04-28    7.90469
# 2020-04-29    8.09437
# 2020-04-30    8.60449
# 2020-05-01    5.43914
# 2020-05-02    5.04428
# 2020-05-03    4.64125
# 2020-05-04    6.25483
# 2020-05-05    5.92006
# 2020-05-06    8.81124
# 2020-05-07    6.74803
# dtype: object

# %%
crescimento.plot()
plt.title('Taxa de Crescimento Diario (%)')
plt.show()

# %% [markdown]
# # **Nova Visualização - Estados Brasileiros**

# %%
# Importando dados do dataset
data = pd.read_csv('https://brasil.io/dataset/covid19/caso?format=csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58728 entries, 0 to 58727
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            58728 non-null  object
#  1   state                           58728 non-null  object
#  2   city                            57271 non-null  object
#  3   place_type                      58728 non-null  object
#  4   confirmed                       58728 non-null  int64
#  5   deaths                          58728 non-null  int64
#  6   is_last                         58728 non-null  bool
#  7   estimated_population_2019       58044 non-null  float64
#  8   city_ibge_code                  58044 non-null  float64
#  9   confirmed_per_100k_inhabitants  56825 non-null  float64
#  10  death_rate                      58728 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
data.head(n = 15)
# Out:
#           date state  ... confirmed_per_100k_inhabitants death_rate
# 0   2020-05-07    AC  ...                       98.32197     0.0667
# 1   2020-05-07    AC  ...                       13.48254     0.0000
# 2   2020-05-07    AC  ...                       38.96357     0.0000
# 3   2020-05-07    AC  ...                       29.41975     0.0000
# 4   2020-05-07    AC  ...                       10.86307     0.0000
# 5   2020-05-07    AC  ...                        2.87522     0.0000
# 6   2020-05-07    AC  ...                            NaN     0.0000
# 7   2020-05-07    AC  ...                       15.80861     0.0000
# 8   2020-05-07    AC  ...                      273.26552     0.0556
# 9   2020-05-07    AC  ...                       16.21271     0.0000
# 10  2020-05-07    AC  ...                      214.81934     0.0354
# 11  2020-05-07    AC  ...                       47.77623     0.0000
# 12  2020-05-07    AC  ...                        4.36224     0.0000
# 13  2020-05-07    AC  ...                       18.79390     0.1250
# 14  2020-05-07    AC  ...                       46.57662     0.0000
#
# [15 rows x 11 columns]

# %%
data.describe()
# Out:
#           confirmed        deaths  ...  confirmed_per_100k_inhabitants    death_rate
# count  58728.000000  58728.000000  ...                    56825.000000  58728.000000
# mean      63.464855      4.122957  ...                       19.789535      0.076071
# std      687.557309     54.745110  ...                       39.439499      0.204293
# min        0.000000      0.000000  ...                        0.002180      0.000000
# 25%        1.000000      0.000000  ...                        3.952180      0.000000
# 50%        2.000000      0.000000  ...                        8.945340      0.000000
# 75%        8.000000      1.000000  ...                       20.582060      0.035700
# max    39928.000000   3206.000000  ...                     1046.199430      1.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# **Manipulando Dados**

# %%
# Dados por estado
data_states = data[data.place_type.eq('state')]
data_states.head(n = 15)
# Out:
#             date state  ... confirmed_per_100k_inhabitants death_rate
# 15    2020-05-07    AC  ...                      114.97446     0.0355
# 72    2020-05-07    AL  ...                       55.94247     0.0525
# 127   2020-05-07    AM  ...                      243.66663     0.0798
# 145   2020-05-07    AP  ...                      260.01175     0.0277
# 309   2020-05-07    BA  ...                       30.44430     0.0364
# 480   2020-05-07    CE  ...                      152.07930     0.0650
# 483   2020-05-07    DF  ...                       74.88555     0.0155
# 563   2020-05-07    ES  ...                       99.23731     0.0394
# 639   2020-05-07    GO  ...                       14.63306     0.0428
# 780   2020-05-07    MA  ...                       83.51730     0.0558
# 1006  2020-05-07    MG  ...                       13.08530     0.0383
# 1032  2020-05-07    MS  ...                       11.19113     0.0322
# 1072  2020-05-07    MT  ...                       12.05350     0.0333
# 1196  2020-05-07    PA  ...                       68.98865     0.0822
# 1284  2020-05-07    PB  ...                       46.01646     0.0600
#
# [15 rows x 11 columns]

# %%
# Segregar dados de casos confirmados e mortes
data_states_confirmed = data_states[['date','state','confirmed']]
data_states_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1457 entries, 15 to 58727
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1457 non-null   object
#  1   state      1457 non-null   object
#  2   confirmed  1457 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 45.5+ KB

# %%
data_states_deaths = data_states[['date','state','deaths']]
data_states_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1457 entries, 15 to 58727
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1457 non-null   object
#  1   state   1457 non-null   object
#  2   deaths  1457 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 45.5+ KB

# %%
# Tabela de população de cada estado em 2019

states_pop = data_states[['state','estimated_population_2019']]
states_pop = states_pop.drop_duplicates()
states_pop.set_index('state', inplace = True)
states_pop
# Out:
#        estimated_population_2019
# state
# AC                      881935.0
# AL                     3337357.0
# AM                     4144597.0
# AP                      845731.0
# BA                    14873064.0
# CE                     9132078.0
# DF                     3015268.0
# ES                     4018650.0
# GO                     7018354.0
# MA                     7075181.0
# MG                    21168791.0
# MS                     2778986.0
# MT                     3484466.0
# PA                     8602865.0
# PB                     4018127.0
# PE                     9557071.0
# PI                     3273227.0
# PR                    11433957.0
# RJ                    17264943.0
# RR                      605761.0
# RS                    11377239.0
# SC                     7164788.0
# SP                    45919049.0
# RN                     3506853.0
# RO                     1777225.0
# SE                     2298696.0
# TO                     1572866.0

# %% [markdown]
# ## **Numero de Casos Confirmados**
# ## **Transformação de dados**

# %%
# Transformar dataframe de long para wide
data_cases = data_states_confirmed.pivot(index='state', columns='date', values='confirmed')
data_cases.head()
# Out:
# date   2020-02-25  2020-02-26  2020-02-27  ...  2020-05-05  2020-05-06  2020-05-07
# state                                      ...
# AC            NaN         NaN         NaN  ...       817.0       943.0      1014.0
# AL            NaN         NaN         NaN  ...      1605.0      1703.0      1867.0
# AM            NaN         NaN         NaN  ...      8109.0      9243.0     10099.0
# AP            NaN         NaN         NaN  ...      1931.0      2046.0      2199.0
# BA            NaN         NaN         NaN  ...      4040.0      4301.0      4528.0
#
# [5 rows x 73 columns]

# %%
# Verificar index das observaçôes
data_cases.index
# Out:
# Index(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS',
#        'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC',
#        'SE', 'SP', 'TO'],
#       dtype='object', name='state')

# %%
# Trocando a indexação de estado por data
data_cases = data_cases.transpose()
data_cases
# Out:
# state           AC      AL       AM      AP  ...      SC     SE       SP     TO
# date                                         ...
# 2020-02-25     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-26     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-27     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-28     NaN     NaN      NaN     NaN  ...     NaN    NaN      2.0    NaN
# 2020-02-29     NaN     NaN      NaN     NaN  ...     NaN    NaN      2.0    NaN
# ...            ...     ...      ...     ...  ...     ...    ...      ...    ...
# 2020-05-03   658.0  1441.0   6683.0  1482.0  ...  2519.0  730.0  31772.0  267.0
# 2020-05-04   733.0  1538.0   7313.0  1733.0  ...  2623.0  772.0  32187.0  303.0
# 2020-05-05   817.0  1605.0   8109.0  1931.0  ...  2795.0  898.0  34053.0  351.0
# 2020-05-06   943.0  1703.0   9243.0  2046.0  ...  2917.0  998.0  37853.0  423.0
# 2020-05-07  1014.0  1867.0  10099.0  2199.0  ...  3082.0    NaN  39928.0    NaN
#
# [73 rows x 27 columns]

# %%
# Verificar a indexação como data
data_cases.index
# Out:
# Index(['2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29',
#        '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10',
#        '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15',
#        '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#        '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30',
#        '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#        '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09',
#        '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14',
#        '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19',
#        '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24',
#        '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28', '2020-04-29',
#        '2020-04-30', '2020-05-01', '2020-05-02', '2020-05-03', '2020-05-04',
#        '2020-05-05', '2020-05-06', '2020-05-07'],
#       dtype='object', name='date')

# %%
# Conversão do index para DateTimeIndex pois está como 'object'
datetime_index = pd.DatetimeIndex(data_cases.index)
data_cases.set_index(datetime_index, inplace = True)
# Verificar o index novamente
data_cases.index
# Out:
# DatetimeIndex(['2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28',
#                '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03',
#                '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07',
#                '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11',
#                '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15',
#                '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19',
#                '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23',
#                '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#                '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31',
#                '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#                '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08',
#                '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12',
#                '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16',
#                '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20',
#                '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24',
#                '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28',
#                '2020-04-29', '2020-04-30', '2020-05-01', '2020-05-02',
#                '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06',
#                '2020-05-07'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
# Existem NAs entre observações válidas, provavlemente houve um falta de informação para aquele estado naquele dia. Vamos considerar este valor igual ao último valor válido para aquele estado.
data_cases.fillna(method='ffill', inplace=True)
data_cases
# Out:
# state           AC      AL       AM      AP  ...      SC     SE       SP     TO
# date                                         ...
# 2020-02-25     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-26     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-27     NaN     NaN      NaN     NaN  ...     NaN    NaN      1.0    NaN
# 2020-02-28     NaN     NaN      NaN     NaN  ...     NaN    NaN      2.0    NaN
# 2020-02-29     NaN     NaN      NaN     NaN  ...     NaN    NaN      2.0    NaN
# ...            ...     ...      ...     ...  ...     ...    ...      ...    ...
# 2020-05-03   658.0  1441.0   6683.0  1482.0  ...  2519.0  730.0  31772.0  267.0
# 2020-05-04   733.0  1538.0   7313.0  1733.0  ...  2623.0  772.0  32187.0  303.0
# 2020-05-05   817.0  1605.0   8109.0  1931.0  ...  2795.0  898.0  34053.0  351.0
# 2020-05-06   943.0  1703.0   9243.0  2046.0  ...  2917.0  998.0  37853.0  423.0
# 2020-05-07  1014.0  1867.0  10099.0  2199.0  ...  3082.0  998.0  39928.0  423.0
#
# [73 rows x 27 columns]

# %% [markdown]
# **Visualização de Dados**

# %%
# Visualizar número totais de caasos por estado
data_cases.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20)
plt.xlabel('Data', fontsize=20);
plt.ylabel('Número de casos confirmados', fontsize=20);
plt.title('COVID19 - Evoluçao de casos confirmados', fontsize=20);

# %%
# Visualizar número totais de casos por estado na escala semi-logarítmica
data_cases.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20, logy = True)
plt.xlabel('Data', fontsize=20);
plt.ylabel('Número de casos confirmados', fontsize=20);
plt.title('Evoluçao de casos confirmados pela COVID-19', fontsize=20);

# %% [markdown]
# # **Visualização de dados alinhando o primeiro dia com 5 casos**

# %%
# Iterar sobre as colunas e valores < 5 serão nulos
for col in data_cases.columns:
    data_cases.loc[(data_cases[col] < 5), col] = None

# Check out tail
data_cases.tail()
# Out:
# state           AC      AL       AM      AP  ...      SC     SE       SP     TO
# date                                         ...
# 2020-05-03   658.0  1441.0   6683.0  1482.0  ...  2519.0  730.0  31772.0  267.0
# 2020-05-04   733.0  1538.0   7313.0  1733.0  ...  2623.0  772.0  32187.0  303.0
# 2020-05-05   817.0  1605.0   8109.0  1931.0  ...  2795.0  898.0  34053.0  351.0
# 2020-05-06   943.0  1703.0   9243.0  2046.0  ...  2917.0  998.0  37853.0  423.0
# 2020-05-07  1014.0  1867.0  10099.0  2199.0  ...  3082.0  998.0  39928.0  423.0
#
# [5 rows x 27 columns]

# %%
# Retirar colunas que tenham tudo NaNs (estados que ainda não chegaram a 5 casos)
data_cases.dropna(axis = 1, how = "all", inplace = True)
data_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 73 entries, 2020-02-25 to 2020-05-07
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AC      49 non-null     float64
#  1   AL      49 non-null     float64
#  2   AM      49 non-null     float64
#  3   AP      40 non-null     float64
#  4   BA      56 non-null     float64
#  5   CE      53 non-null     float64
#  6   DF      55 non-null     float64
#  7   ES      53 non-null     float64
#  8   GO      53 non-null     float64
#  9   MA      46 non-null     float64
#  10  MG      53 non-null     float64
#  11  MS      52 non-null     float64
#  12  MT      46 non-null     float64
#  13  PA      46 non-null     float64
#  14  PB      44 non-null     float64
#  15  PE      55 non-null     float64
#  16  PI      47 non-null     float64
#  17  PR      57 non-null     float64
#  18  RJ      57 non-null     float64
#  19  RN      49 non-null     float64
#  20  RO      45 non-null     float64
#  21  RR      45 non-null     float64
#  22  RS      53 non-null     float64
#  23  SC      55 non-null     float64
#  24  SE      53 non-null     float64
#  25  SP      64 non-null     float64
#  26  TO      47 non-null     float64
# dtypes: float64(27)
# memory usage: 16.0 KB

# %%
# Criar dataframe com a data do primeiro dia com o 5o caso em cada estado
date_5th_cases = data_cases.apply(pd.Series.first_valid_index)
df_5th_cases = pd.DataFrame(date_5th_cases)
df_5th_cases
# Out:
#                0
# state
# AC    2020-03-20
# AL    2020-03-20
# AM    2020-03-20
# AP    2020-03-29
# BA    2020-03-13
# CE    2020-03-16
# DF    2020-03-14
# ES    2020-03-16
# GO    2020-03-16
# MA    2020-03-23
# MG    2020-03-16
# MS    2020-03-17
# MT    2020-03-23
# PA    2020-03-23
# PB    2020-03-25
# PE    2020-03-14
# PI    2020-03-22
# PR    2020-03-12
# RJ    2020-03-12
# RN    2020-03-20
# RO    2020-03-24
# RR    2020-03-24
# RS    2020-03-16
# SC    2020-03-14
# SE    2020-03-16
# SP    2020-03-05
# TO    2020-03-22

# %%
# Resetar o index, retirar a coluna de data
data_cases_drop = data_cases.reset_index().drop(['date'], axis = 1)
data_cases_drop.head()
# Out:
# state  AC  AL  AM  AP  BA  CE  DF  ES  GO  ...  RJ  RN  RO  RR  RS  SC  SE  SP  TO
# 0     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4     NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 27 columns]

# %%
# Trazer para cima os dados a partir do primeiro dado válido (shift)
for col in data_cases_drop.columns:
    data_cases_drop[col] = data_cases_drop[col].shift(-data_cases_drop[col].first_valid_index())
# check out head
data_cases_drop
# Out:
# state    AC    AL    AM    AP    BA    CE  ...    RR    RS    SC   SE    SP   TO
# 0       7.0   6.0   7.0   8.0   7.0   9.0  ...   8.0   8.0   5.0  5.0   6.0  5.0
# 1      11.0   7.0  11.0   8.0   7.0  10.0  ...   8.0   8.0   6.0  5.0  10.0  7.0
# 2      11.0   7.0  26.0  10.0   9.0  19.0  ...  10.0  19.0   7.0  6.0  13.0  7.0
# 3      17.0   8.0  32.0  11.0  10.0  24.0  ...  12.0  31.0   7.0  6.0  16.0  7.0
# 4      21.0  10.0  47.0  12.0  14.0  68.0  ...  16.0  43.0  14.0  7.0  16.0  8.0
# ..      ...   ...   ...   ...   ...   ...  ...   ...   ...   ...  ...   ...  ...
# 68      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  NaN   NaN  NaN
# 69      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  NaN   NaN  NaN
# 70      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  NaN   NaN  NaN
# 71      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  NaN   NaN  NaN
# 72      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  NaN   NaN  NaN
#
# [73 rows x 27 columns]

# %%
# Evolução na escala semi-logarítimica 
data_cases_drop.plot(figsize=(20,10), linewidth=2, marker='.', fontsize=20, logy = True)
plt.xlabel('Dias', fontsize=20);
plt.ylabel('Número de Casos Confirmados', fontsize=20);
plt.title('Total de casos confirmados nos estados (a partir de 5 casos)', fontsize=20);

# %% [markdown]
# # **Visualização interativa com Altair**

# %%
# Transformar dados em long para utilizar no altair
# Endereço da Biblioteca: https://matthewkudija.com/blog/2018/06/22/altair-interactive/
cases_long = data_cases_drop.reset_index().melt(id_vars = 'index', value_name = 'confirmed').rename(columns={'index':'Day'})
cases_long
# Out:
#       Day state  confirmed
# 0       0    AC        7.0
# 1       1    AC       11.0
# 2       2    AC       11.0
# 3       3    AC       17.0
# 4       4    AC       21.0
# ...   ...   ...        ...
# 1966   68    TO        NaN
# 1967   69    TO        NaN
# 1968   70    TO        NaN
# 1969   71    TO        NaN
# 1970   72    TO        NaN
#
# [1971 rows x 3 columns]

# %%
# Adicionar primeiro dia da 5a morte por estado
cases_long = cases_long.merge(df_5th_cases, left_on='state', right_index=True, how='left')
cases_long
# Out:
#       Day state  confirmed          0
# 0       0    AC        7.0 2020-03-20
# 1       1    AC       11.0 2020-03-20
# 2       2    AC       11.0 2020-03-20
# 3       3    AC       17.0 2020-03-20
# 4       4    AC       21.0 2020-03-20
# ...   ...   ...        ...        ...
# 1966   68    TO        NaN 2020-03-22
# 1967   69    TO        NaN 2020-03-22
# 1968   70    TO        NaN 2020-03-22
# 1969   71    TO        NaN 2020-03-22
# 1970   72    TO        NaN 2020-03-22
#
# [1971 rows x 4 columns]

# %%
# Adicionar coluna com a data de cada observação
from datetime import datetime  
from datetime import timedelta 
cases_long['Date'] = cases_long.iloc[:,3] + cases_long['Day'].map(timedelta)
cases_long
# Out:
#       Day state  confirmed          0       Date
# 0       0    AC        7.0 2020-03-20 2020-03-20
# 1       1    AC       11.0 2020-03-20 2020-03-21
# 2       2    AC       11.0 2020-03-20 2020-03-22
# 3       3    AC       17.0 2020-03-20 2020-03-23
# 4       4    AC       21.0 2020-03-20 2020-03-24
# ...   ...   ...        ...        ...        ...
# 1966   68    TO        NaN 2020-03-22 2020-05-29
# 1967   69    TO        NaN 2020-03-22 2020-05-30
# 1968   70    TO        NaN 2020-03-22 2020-05-31
# 1969   71    TO        NaN 2020-03-22 2020-06-01
# 1970   72    TO        NaN 2020-03-22 2020-06-02
#
# [1971 rows x 5 columns]

# %%
# Remover coluna com primeiro dia da 5a morte
cases_long = cases_long.drop([cases_long.columns[3]] ,  axis='columns')
cases_long
# Out:
#       Day state  confirmed       Date
# 0       0    AC        7.0 2020-03-20
# 1       1    AC       11.0 2020-03-21
# 2       2    AC       11.0 2020-03-22
# 3       3    AC       17.0 2020-03-23
# 4       4    AC       21.0 2020-03-24
# ...   ...   ...        ...        ...
# 1966   68    TO        NaN 2020-05-29
# 1967   69    TO        NaN 2020-05-30
# 1968   70    TO        NaN 2020-05-31
# 1969   71    TO        NaN 2020-06-01
# 1970   72    TO        NaN 2020-06-02
#
# [1971 rows x 4 columns]

# %%
# Adicionar população por estado
cases_long = cases_long.merge(states_pop, left_on='state', right_index=True, how='left')
cases_long.head()
# Out:
#    Day state  confirmed       Date  estimated_population_2019
# 0    0    AC        7.0 2020-03-20                   881935.0
# 1    1    AC       11.0 2020-03-21                   881935.0
# 2    2    AC       11.0 2020-03-22                   881935.0
# 3    3    AC       17.0 2020-03-23                   881935.0
# 4    4    AC       21.0 2020-03-24                   881935.0

# %%
# Adicionar taxa de casos a cada 100.000 habitantes
cases_long['CasesPop'] = cases_long['confirmed']/cases_long['estimated_population_2019']*100000
cases_long.head()
# Out:
#    Day state  confirmed       Date  estimated_population_2019  CasesPop
# 0    0    AC        7.0 2020-03-20                   881935.0  0.793709
# 1    1    AC       11.0 2020-03-21                   881935.0  1.247257
# 2    2    AC       11.0 2020-03-22                   881935.0  1.247257
# 3    3    AC       17.0 2020-03-23                   881935.0  1.927580
# 4    4    AC       21.0 2020-03-24                   881935.0  2.381128

# %%
# drop NaNs
cases_long = cases_long.dropna()
cases_long
# Out:
#       Day state  confirmed       Date  estimated_population_2019   CasesPop
# 0       0    AC        7.0 2020-03-20                   881935.0   0.793709
# 1       1    AC       11.0 2020-03-21                   881935.0   1.247257
# 2       2    AC       11.0 2020-03-22                   881935.0   1.247257
# 3       3    AC       17.0 2020-03-23                   881935.0   1.927580
# 4       4    AC       21.0 2020-03-24                   881935.0   2.381128
# ...   ...   ...        ...        ...                        ...        ...
# 1940   42    TO      267.0 2020-05-03                  1572866.0  16.975381
# 1941   43    TO      303.0 2020-05-04                  1572866.0  19.264197
# 1942   44    TO      351.0 2020-05-05                  1572866.0  22.315951
# 1943   45    TO      423.0 2020-05-06                  1572866.0  26.893582
# 1944   46    TO      423.0 2020-05-07                  1572866.0  26.893582
#
# [1371 rows x 6 columns]

# %%
import altair as alt

# Selection tool
selection = alt.selection_single(fields=['state'])
# Color change when clicked
color = alt.condition(selection,
                    alt.Color('state:N'),
                    alt.value('lightgray'))


# Base altair plot 
base = alt.Chart(cases_long, title="COVID19 - Total de casos confirmados por estado brasileiro").mark_line(strokeWidth=4, opacity=0.7).encode(
    x=alt.X('Day'),
    y=alt.Y('confirmed', scale=alt.Scale(type='log')),
    color=alt.Color('state', legend=None),
).properties(
    width=650,
    height=800
)

# Chart
chart = base.encode(
  color=alt.condition(selection, 'state:N', alt.value('lightgray')),
  tooltip=['state:N', 'yearmonthdate(Date):N', 'confirmed:N']
).add_selection(
  selection
)

# Overlay
overlay = base.encode(
  color='state',
  opacity=alt.value(0.5),
).transform_filter(
  selection
)

# Text labels
text = base.mark_text(
    align='left',
    dx=5,
    size=15
).encode(
    x=alt.X('Day', aggregate='max',  axis=alt.Axis(title='Dias a partir do 5o. caso no estado')),
    y=alt.Y('confirmed', aggregate={'argmax': 'Day'}, axis=alt.Axis(title='Casos confirmados (escala logarítmica)')),
    text='state'
).transform_filter(
    selection
)

# Add doubling line

## Death doubles every 2 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/2)) < cases_long.confirmed.max():
      j = i+2

source2 = alt.sequence(start=0, stop=j, step=1, as_='x')

double2 = alt.Chart(source2).mark_line(strokeDash=[2,2]).transform_calculate(
    double2='5*pow(2,(datum.x/2))'
).transform_fold(
    ['double2']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text2 = alt.Chart({'values':[{'x': 13, 'y': 500}]}).mark_text(
    text='casos duplicam a cada 2 dias', angle=305,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

## Cases doubles every 5 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/5)) < cases_long.confirmed.max():
      j = i+2

source5 = alt.sequence(start=0, stop=j, step=1, as_='x')

double5 = alt.Chart(source5).mark_line(strokeDash=[2,2]).transform_calculate(
    double5='5*pow(2,(datum.x/5))'
).transform_fold(
    ['double5']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text5 = alt.Chart({'values':[{'x': 24, 'y': 150}]}).mark_text(
    text='a cada 5 dias', angle=329,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

## Cases doubles every 10 days
j = 0
for i in range(0,cases_long.Day.max()):
    if 5*pow(2,(i/10)) < cases_long.confirmed.max():
      j = i+2

source10 = alt.sequence(start=0, stop=j, step=1, as_='x')

double10 = alt.Chart(source10).mark_line(strokeDash=[2,2]).transform_calculate(
    double10='5*pow(2,(datum.x/10))'
).transform_fold(
    ['double10']
).encode(
    x='x:Q',
    y='value:Q',
    color=alt.value('lightgray')
)

text10 = alt.Chart({'values':[{'x': 24, 'y': 28}]}).mark_text(
    text='a cada 10 dias', angle=343,
    size=13,
    color = 'gray'
).encode(
    x='x:Q', y='y:Q'
)

# Sum it all up
alt.layer(chart, overlay, text, double2, double5, double10, text2, text5, text10).configure_axis(
    labelFontSize=15,
    titleFontSize=20
).configure_title(
    fontSize=23
)


# Sum em up!
#chart + overlay + text
# Out:
# alt.LayerChart(...)

# %%
# Mortes por habitantes

# Base altair plot 
basepop = alt.Chart(cases_long, title="COVID19 - Casos confirmados a cada 100 mil habitantes").mark_line(strokeWidth=4, opacity=0.7).encode(
    x=alt.X('Day'),
    y=alt.Y('confirmed'),
    color=alt.Color('state', legend=None),
).properties(
    width=650,
    height=800
)

# Chart
chartpop = basepop.encode(
  color=alt.condition(selection, 'state:N', alt.value('lightgray')),
  tooltip=['state:N', 'yearmonthdate(Date):N', 'confirmed:N']
).add_selection(
  selection
)

# Overlay
overlaypop = basepop.encode(
  color='state',
  opacity=alt.value(0.5),
).transform_filter(
  selection
)

# Text labels
textpop = basepop.mark_text(
    align='left',
    dx=5,
    size=15
).encode(
    x=alt.X('Day', aggregate='max',  axis=alt.Axis(title='Dias a partir do 5. caso no estado')),
    y=alt.Y('confirmed', aggregate={'argmax': 'Day'}, axis=alt.Axis(title='Casos confirmados a cada 100 mil habitantes')),
    text='state'
).transform_filter(
    selection
)

# Sum em up!
alt.layer(chartpop + overlaypop + textpop).configure_axis(
    labelFontSize=15,
    titleFontSize=20
).configure_title(
    fontSize=23
)
# Out:
# alt.LayerChart(...)
